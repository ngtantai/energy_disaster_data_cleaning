# %%
import pandas as pd
import numpy as np
import re
import pycountry
from textblob import TextBlob
from calendar import month_name
from collections import Counter

# %%
file = 'nuclear_indcident_1952_2011.xlsx'
data = pd.read_excel(file)

# %%
# df = pd.DataFrame(data=data, columns=['Year', 'Cause of Loss', 'Deaths', 'Loss Estimated ($)', 'Location', 'Text'])
df = pd.DataFrame(data=data)
df
# Out:
#          Date                                           Location  \
# 0  2011-09-12                                   Marcoule, France
# 1  2011-03-12                                   Fukushima, Japan
# 2  2006-07-25                                   Forsmark, Sweden
# 3  2004-08-09                            Fukui Prefecture, Japan
# 4  2002-02-16                    Oak Harbor, Ohio, United States
# 5  1999-09-30                          Ibaraki Prefecture, Japan
# 6  1996-09-02              Crystal River, Florida, United States
# 7  1996-02-20              Waterford, Connecticut, United States
# 8  1992-03-01             Sosnovyi Bor, Leningrad Oblast, Russia
# 9  1989-03-17                     Lusby, Maryland, United States
# 10 1987-12-19                  Lycoming, New York, United States
# 11 1987-03-31                 Delta, Pennsylvania, United States
# 12 1986-05-04                         Hamm-Uentrop, West Germany
# 13 1986-04-26  Chernobyl, Chernobyl Raion (Now Ivankiv Raion)...
# 14 1986-04-11             Plymouth, Massachusetts, United States
# 15 1985-03-09                     Athens, Alabama, United States
# 16 1984-09-15                     Athens, Alabama, United States
# 17 1979-03-28     Three Mile Island, Pennsylvania, United States
# 18 1977-02-22                 Jaslovské Bohunice, Czechoslovakia
# 19 1976-01-05                 Jaslovské Bohunice, Czechoslovakia
# 20 1975-12-07                           Greifswald, East Germany
# 21 1905-05-28             Sosnovyi Bor, Leningrad Oblast, Russia
# 22 1969-01-21                  Lucens reactor, Vaud, Switzerland
# 23 1966-10-05  Frenchtown Charter Township, Michigan, United ...
# 24 1961-01-03                  Idaho Falls, Idaho, United States
# 25 1957-10-10  Sellafield aka Windscale fire, Cumberland, Uni...
# 26 1957-09-29                             Mayak, Kyshtym, Russia
# 27 1957-07-26             Simi Valley, California, United States
#
#                                                  Text  \
# 0   One person was killed and four injured, one se...
# 1   A tsunami flooded and damaged the plant's 5 ac...
# 2   An electrical fault at Forsmark Nuclear Power ...
# 3   Steam explosion at Mihama Nuclear Power Plant ...
# 4   Severe corrosion of control rod forces 24-mont...
# 5   Tokaimura nuclear accident killed two workers,...
# 6   Balance-of-plant equipment malfunction forces ...
# 7   Leaking valve forces shutdown Millstone Nuclea...
# 8   An accident at the Sosnovy Bor nuclear plant l...
# 9   Inspections at Calvert Cliff Units 1 and 2 rev...
# 10  Malfunctions force Niagara Mohawk Power Corpor...
# 11  Peach Bottom units 2 and 3 shutdown due to coo...
# 12  Experimental THTR-300 reactor releases small a...
# 13  Overheating, steam explosion, fire, and meltdo...
# 14  Recurring equipment problems force emergency s...
# 15  Instrumentation systems malfunction during sta...
# 16  Safety violations, operator error, and design ...
# 17  Loss of coolant and partial core meltdown due ...
# 18  Severe corrosion of reactor and release of rad...
# 19  Malfunction during fuel replacement. Fuel rod ...
# 20  Electrical error causes fire in the main troug...
# 21  There was reportedly a partial nuclear meltdow...
# 22  On January 21, 1969, it suffered a loss-of-coo...
# 23  Partial core meltdown of the Fermi 1 Reactor a...
# 24  Explosion at SL-1 prototype at the National Re...
# 25  A fire at the British atomic bomb project dest...
# 26  The Kyshtym disaster was a radiation contamina...
# 27  Partial core meltdown at Santa Susana Field La...
#
#                                                Deaths  \
# 0                                                   1
# 1                                                  2+
# 2                                                   0
# 3                                                   4
# 4                                                   0
# 5                                                   2
# 6                                                   0
# 7                                                   0
# 8                                                 NaN
# 9                                                   0
# 10                                                  0
# 11                                                  0
# 12                                                  0
# 13  30 direct, 19 not entirely related and 15 mino...
# 14                                                  0
# 15                                                  0
# 16                                                  0
# 17                                                  0
# 18                                                  0
# 19                                                  2
# 20                                                  0
# 21                                                NaN
# 22                                                  0
# 23                                                  0
# 24                                                  3
# 25                                                  0
# 26                                                NaN
# 27                                                  0
#
#    Loss estimated ($ millions)
# 0                          NaN
# 1                          NaN
# 2                          100
# 3                            9
# 4                          143
# 5                           54
# 6                          384
# 7                          254
# 8                          NaN
# 9                          120
# 10                         150
# 11                         400
# 12                         267
# 13                        6700
# 14                        1001
# 15                        1830
# 16                         110
# 17                        2400
# 18                        1700
# 19                         NaN
# 20                         443
# 21                         NaN
# 22                         NaN
# 23                     132[24]
# 24                          22
# 25                         NaN
# 26                         NaN
# 27                          32

# %%
df.head()
# Out:
#    Year                             Cause of Loss           Deaths  \
# 0  1900                          Tropical cyclone  6,000 to 12,000
# 1  1906  Earthquakeand fire (urban conflagration)           3,000+
# 2  2001                                 Terrorism             2996
# 4  1928                          Tropical cyclone             2812
# 6  1941                 Military strike - bombing             2467
#
#         Loss Estimated (US$)                Cause of Loss.1  \
# 0  $28,000,000 (approximate)       1900 Galveston hurricane
# 1                        NaN  1906 San Francisco earthquake
# 2               178000000000           September 11 attacks
# 4                  800000000      1928 Okeechobee hurricane
# 6                        NaN         Attack on Pearl Harbor
#
#                                             Location  \
# 0                                              Texas
# 1                          San Francisco, California
# 2  New York City, Arlington County, Virginia, and...
# 4                               Florida, Puerto Rico
# 6                                   Honolulu, Hawaii
#
#                                                 Text
# 0  Fatalities estimated. Remains the deadliest na...
# 1  Conflagration followed quake; fatalities estim...
# 2  2,977 victims and 19 hijackers. Costliest disa...
# 4  4,078 believed dead total. 2500 in Florida, 31...
# 6      2,403 U.S. victims and 64 Japanese attackers.

# %%
df['Location'] =df['Location'].apply(lambda x: re.findall(r'\d.*0',str(x)))
df['Loss Estimated (US$)'] =df['Loss Estimated (US$)'].apply(lambda x: str(x).replace(',',"").replace('[',"")
                                                                             .replace(']', "")
                                                                             .replace('\'',""))
# df['Loss Estimated (US$)'] =df['Loss Estimated (US$)'].apply(lambda x: re.findall(r'^\[\d+0',str(x)))
# Out:
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df
# Out:
#      Year                             Cause of Loss           Deaths  \
# 0    1900                          Tropical cyclone  6,000 to 12,000
# 1    1906  Earthquakeand fire (urban conflagration)           3,000+
# 2    2001                                 Terrorism             2996
# 4    1928                          Tropical cyclone             2812
# 6    1941                 Military strike - bombing             2467
# 7    1889                      Accident - Dam burst             2209
# 8    1893                          Tropical cyclone             2000
# 9    2005                          Tropical cyclone             1836
# 10   1865                      Accident - Shipwreck             1700
# 11   1980                                 Heat wave             1700
# 12   1871                              Fire (rural)      1,500-2,500
# 13   1904                      Accident - Shipwreck             1021
# 14   1893                          Tropical cyclone      1,000-2,000
# 15   1978                     Mass murder - suicide              909
# 16   1945                                 Shipwreck              879
# 17   1915                      Accident - Shipwreck              844
# 18   1995                                 Heat wave              739
# 19   1925                                   Tornado          695-747
# 21   1903                           Fire (building)              602
# 22   1919                          Tropical cyclone              600
# 23   1928                    Accident - Dam failure              600
# 24   1938                          Tropical cyclone              600
# 25   1947                      Accident - Explosion              581
# 26   1871                                      Fire  500 (estimated)
# 27   1942                           Fire (building)              492
# 28   1927                   Exploitation, Silicosis       476-1,000+
# 29   1918                              Fire (rural)              453
# 30   1936                          Tornado outbreak             436+
# 31   1913                                     Flood              428
# 32   1957                          Tropical cyclone              416
# ..    ...                                       ...              ...
# 342  1910                                   Bombing               21
# 343  1915                            Fire(building)               21
# 344  1919                      Accident - Explosion               21
# 346  1986                       Accident - tour bus               21
# 347  1872                Fire (urban conflagration)               20
# 349  1907                       Accident - Railroad               20
# 350  2005                      Accident - Shipwreck               20
# 351  2010                                     Flood               20
# 352  1897                       Accident - Railroad               19
# 353  1944                       Accident - Aircraft               19
# 354  2013                                  Wildfire               19
# 355  1861                       Accident - Railroad         17 to 20
# 356  1903                       Accident - Railroad               17
# 357  2000                                 Terrorism               17
# 358  1965            Accidents - Pipeline accidents               17
# 359  1966                               Mass murder               17
# 360  1991                     Accident - Automobile               17
# 361  2002                               Mass murder               17
# 363  1926                                   Tornado               16
# 364  1978                       Accident - Railroad               16
# 365  1987                       Accident - Railroad               16
# 366  1987                               Mass Murder               16
# 368  2015                                 Terrorism               16
# 369  2016                Accident - Hot air balloon               16
# 370  2017                                  blizzard            16-19
# 371  1954                            Fire(building)               15
# 372  1986                               Mass murder               15
# 373  1999                               Mass murder               15
# 374  2011                       Accident - tour bus               15
# 375  2013                      Accident - Explosion               15
#
#     Loss Estimated (US$)                           Cause of Loss.1  \
# 0               28000000                  1900 Galveston hurricane
# 1                                    1906 San Francisco earthquake
# 2           178000000000                      September 11 attacks
# 4              800000000                 1928 Okeechobee hurricane
# 6                                           Attack on Pearl Harbor
# 7                                                  Johnstown Flood
# 8                                 1893 Cheniere Caminada hurricane
# 9           108000000000                         Hurricane Katrina
# 10                                                         Sultana
# 11                                    1980 United States heat wave
# 12                                                   Peshtigo Fire
# 13                                               PS General Slocum
# 14                                      1893 Sea Islands hurricane
# 15                                                       Jonestown
# 16                                             USS Indianapolis[1]
# 17                                                   S.S. Eastland
# 18                                       Chicago Heat Wave of 1995
# 19            1650000000                         Tri-State Tornado
# 21                                           Iroquois Theatre fire
# 22                                     1919 Florida Keys hurricane
# 23                                                 St. Francis Dam
# 24                                      1938 New England hurricane
# 25                                             Texas City disaster
# 26                                             Great Michigan Fire
# 27                                             Cocoanut Grove fire
# 28                                      Hawks Nest Tunnel disaster
# 29               7300000                         1918 Cloquet fire
# 30                        1936 Tupelo–Gainesville tornado outbreak
# 31                                     1913 (Ohio) statewide flood
# 32             147000000                          Hurricane Audrey
# ..                   ...                                       ...
# 342                                       Los Angeles Timesbombing
# 343                                          St. Johns School fire
# 344           6600000000                      Great Molasses Flood
# 346                                                            NaN
# 347             73500000                 Great Boston fire of 1872
# 349                                            Woodlawn derailment
# 350                                    Ethan Allenboating accident
# 351                                      June 2010 Arkansas floods
# 352                                           Garrison train crash
# 353                                        Long Creek air disaster
# 354                                              Yarnell Hill Fire
# 355                                 Platte Bridge Railroad Tragedy
# 356                                                   Purdue Wreck
# 357                                               USS Cole bombing
# 358                                    Pipeline explosion and fire
# 359                                   University of Texas massacre
# 360                                            Dust storm accident
# 361                                         Beltway sniper attacks
# 363                                       La Plata tornado of 1926
# 364                         Waverly, Tennessee, tank car explosion
# 365                                  1987 Maryland train collision
# 366                                             The Dover massacre
# 368                                     2015 San Bernardino attack
# 369                            2016 Lockhart hot air balloon crash
# 370                             March 2017 North American blizzard
# 371                              Cleveland Hill Middle School fire
# 372                                    Edmond post office shooting
# 373                                 Columbine High School massacre
# 374                                     World Wide Tours bus crash
# 375                              West Fertilizer Company explosion
#
#                                               Location  \
# 0                                                Texas
# 1                            San Francisco, California
# 2    New York City, Arlington County, Virginia, and...
# 4                                 Florida, Puerto Rico
# 6                                     Honolulu, Hawaii
# 7                                         Pennsylvania
# 8                                            Louisiana
# 9    Florida, Louisiana, Mississippi, Alabama, Geor...
# 10                 Marion, Arkansas / Helena, Arkansas
# 11                         Central and southern states
# 12    Peshtigo, Wisconsin, Upper Peninsula of Michigan
# 13                       East River near New York City
# 14                             Georgia, South Carolina
# 15                                  Georgetown, Guyana
# 16                                      Philippine Sea
# 17                                   Chicago, Illinois
# 18                                   Chicago, Illinois
# 19   Missouri, Illinois and Indiana(Kentucky, Tenne...
# 21                                   Chicago, Illinois
# 22                                      Florida, Texas
# 23                           Santa Clarita, California
# 24                                                 NaN
# 25                                   Texas City, Texas
# 26                                            Michigan
# 27                               Boston, Massachusetts
# 28                        Gauley Bridge, West Virginia
# 29                                           Minnesota
# 30   Alabama, Arkansas, Mississippi, Georgia, South...
# 31                                                Ohio
# 32              Louisiana, Texas, Mississippi, Alabama
# ..                                                 ...
# 342                            Los Angeles, California
# 343                             Peabody, Massachusetts
# 344                              Boston, Massachusetts
# 346                                 Walker, California
# 347                              Boston, Massachusetts
# 349                 Woodlawn, The Bronx, New York City
# 350                             Lake George (New York)
# 351  Albert Pike Recreation Area near Langley, Arka...
# 352                                 Garrison, New York
# 353                              South Portland, Maine
# 354                                   Yarnell, Arizona
# 355                               St. Joseph, Missouri
# 356                              Indianapolis, Indiana
# 357                                        Aden, Yemen
# 358                            Natchitoches, Louisiana
# 359                                      Austin, Texas
# 360                               Coalinga, California
# 361                       Washington metropolitan area
# 363                                 La Plata, Maryland
# 364                                 Waverly, Tennessee
# 365                                    Chase, Maryland
# 366           Dover, Arkansas - Russellville, Arkansas
# 368                         San Bernardino, California
# 369                                    Lockhart, Texas
# 370  Northeastern United States, Upper Midwest, Gre...
# 371                              Cheektowaga, New York
# 372                                   Edmond, Oklahoma
# 373                         Jefferson County, Colorado
# 374                                    Bronx, New York
# 375                                        West, Texas
#
#                                                   Text
# 0    Fatalities estimated. Remains the deadliest na...
# 1    Conflagration followed quake; fatalities estim...
# 2    2,977 victims and 19 hijackers. Costliest disa...
# 4    4,078 believed dead total. 2500 in Florida, 31...
# 6        2,403 U.S. victims and 64 Japanese attackers.
# 7                 Much rain, deforestation; dam failed
# 8                                 Fatalities estimated
# 9          Costliest natural disaster in U.S. history.
# 10   Steamboat sank due to boiler explosion; fatali...
# 11           Official death toll, may have been higher
# 12   Fatalities estimated; most deaths in single fi...
# 13                 Steamship sank due to fire on board
# 14                                Fatalities estimated
# 15   Cult leader of the Peoples Temple Agricultural...
# 16   Largest loss of life in the history of the U.S...
# 17   Passenger ship capsized in Chicago harbor, cau...
# 18                                                 NaN
# 19   Lower number for single 3-state tornado; highe...
# 21   Worst theater fire in American history; worst ...
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                       Ammonium nitrate onboard ship
# 26                                                 NaN
# 27   Nightclub fire; loss of life due to blocked ex...
# 28   178 admitted deaths, 476 with congressional in...
# 29                                                 NaN
# 30   Two tornadoes in Tupelo, Mississippi, and Gain...
# 31                                                 NaN
# 32                                                 NaN
# ..                                                 ...
# 342                                                NaN
# 343  Schoolgirls trapped behind exit door; resulted...
# 344  Damages are out-of-court settlements only; rep...
# 346                                                NaN
# 347                                                NaN
# 349  The day after the New York Central Railroad in...
# 350  Overloaded tour boat capsized from another boa...
# 351                                                NaN
# 352                                                NaN
# 353                                                NaN
# 354  19 firefighters were killed trapped when they ...
# 355                                                NaN
# 356                                                NaN
# 357                                                NaN
# 358                                                NaN
# 359                                                NaN
# 360                                                NaN
# 361  3 injured in the Beltway sniper attacks and 7 ...
# 363            13 killed in La Plata Elementary School
# 364                           An additional 43 injured
# 365                                                NaN
# 366                                                NaN
# 368                           An additional 24 injured
# 369      Deadliest ballooning disaster in U.S. history
# 370                                                NaN
# 371                                                NaN
# 372                       14 victims and 1 perpetrator
# 373  Armed with 2 sawed-off shotguns, a TEC-9 pisto...
# 374           En route to Connecticut casino, March 12
# 375                 More than 160 people were injured.
#
# [331 rows x 7 columns]

# %%
# df['Loss Estimated (US$)'] =df['Loss Estimated (US$)'].apply(lambda x: str(x).replace('[',"")
#                                                                              .replace(']', "")
#                                                                              .replace('\'',"").replace('(',""))
df['Loss Estimated (US$)'] =df['Loss Estimated (US$)'].apply(lambda x: re.findall(r'^\d+0',str(x)))
df['Loss Estimated (US$)'] =df['Loss Estimated (US$)'].apply(lambda x: str(x).replace(',',"").replace('[',"")
                                                                             .replace(']', "")
                                                                             .replace('\'',""))
# Out:
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
df
# Out:
#      Year                             Cause of Loss           Deaths  \
# 0    1900                          Tropical cyclone  6,000 to 12,000
# 1    1906  Earthquakeand fire (urban conflagration)           3,000+
# 2    2001                                 Terrorism             2996
# 4    1928                          Tropical cyclone             2812
# 6    1941                 Military strike - bombing             2467
# 7    1889                      Accident - Dam burst             2209
# 8    1893                          Tropical cyclone             2000
# 9    2005                          Tropical cyclone             1836
# 10   1865                      Accident - Shipwreck             1700
# 11   1980                                 Heat wave             1700
# 12   1871                              Fire (rural)      1,500-2,500
# 13   1904                      Accident - Shipwreck             1021
# 14   1893                          Tropical cyclone      1,000-2,000
# 15   1978                     Mass murder - suicide              909
# 16   1945                                 Shipwreck              879
# 17   1915                      Accident - Shipwreck              844
# 18   1995                                 Heat wave              739
# 19   1925                                   Tornado          695-747
# 21   1903                           Fire (building)              602
# 22   1919                          Tropical cyclone              600
# 23   1928                    Accident - Dam failure              600
# 24   1938                          Tropical cyclone              600
# 25   1947                      Accident - Explosion              581
# 26   1871                                      Fire  500 (estimated)
# 27   1942                           Fire (building)              492
# 28   1927                   Exploitation, Silicosis       476-1,000+
# 29   1918                              Fire (rural)              453
# 30   1936                          Tornado outbreak             436+
# 31   1913                                     Flood              428
# 32   1957                          Tropical cyclone              416
# ..    ...                                       ...              ...
# 342  1910                                   Bombing               21
# 343  1915                            Fire(building)               21
# 344  1919                      Accident - Explosion               21
# 346  1986                       Accident - tour bus               21
# 347  1872                Fire (urban conflagration)               20
# 349  1907                       Accident - Railroad               20
# 350  2005                      Accident - Shipwreck               20
# 351  2010                                     Flood               20
# 352  1897                       Accident - Railroad               19
# 353  1944                       Accident - Aircraft               19
# 354  2013                                  Wildfire               19
# 355  1861                       Accident - Railroad         17 to 20
# 356  1903                       Accident - Railroad               17
# 357  2000                                 Terrorism               17
# 358  1965            Accidents - Pipeline accidents               17
# 359  1966                               Mass murder               17
# 360  1991                     Accident - Automobile               17
# 361  2002                               Mass murder               17
# 363  1926                                   Tornado               16
# 364  1978                       Accident - Railroad               16
# 365  1987                       Accident - Railroad               16
# 366  1987                               Mass Murder               16
# 368  2015                                 Terrorism               16
# 369  2016                Accident - Hot air balloon               16
# 370  2017                                  blizzard            16-19
# 371  1954                            Fire(building)               15
# 372  1986                               Mass murder               15
# 373  1999                               Mass murder               15
# 374  2011                       Accident - tour bus               15
# 375  2013                      Accident - Explosion               15
#
#     Loss Estimated (US$)                           Cause of Loss.1  \
# 0               28000000                  1900 Galveston hurricane
# 1                                    1906 San Francisco earthquake
# 2           178000000000                      September 11 attacks
# 4              800000000                 1928 Okeechobee hurricane
# 6                                           Attack on Pearl Harbor
# 7                                                  Johnstown Flood
# 8                                 1893 Cheniere Caminada hurricane
# 9           108000000000                         Hurricane Katrina
# 10                                                         Sultana
# 11                                    1980 United States heat wave
# 12                                                   Peshtigo Fire
# 13                                               PS General Slocum
# 14                                      1893 Sea Islands hurricane
# 15                                                       Jonestown
# 16                                             USS Indianapolis[1]
# 17                                                   S.S. Eastland
# 18                                       Chicago Heat Wave of 1995
# 19            1650000000                         Tri-State Tornado
# 21                                           Iroquois Theatre fire
# 22                                     1919 Florida Keys hurricane
# 23                                                 St. Francis Dam
# 24                                      1938 New England hurricane
# 25                                             Texas City disaster
# 26                                             Great Michigan Fire
# 27                                             Cocoanut Grove fire
# 28                                      Hawks Nest Tunnel disaster
# 29               7300000                         1918 Cloquet fire
# 30                        1936 Tupelo–Gainesville tornado outbreak
# 31                                     1913 (Ohio) statewide flood
# 32             147000000                          Hurricane Audrey
# ..                   ...                                       ...
# 342                                       Los Angeles Timesbombing
# 343                                          St. Johns School fire
# 344           6600000000                      Great Molasses Flood
# 346                                                            NaN
# 347             73500000                 Great Boston fire of 1872
# 349                                            Woodlawn derailment
# 350                                    Ethan Allenboating accident
# 351                                      June 2010 Arkansas floods
# 352                                           Garrison train crash
# 353                                        Long Creek air disaster
# 354                                              Yarnell Hill Fire
# 355                                 Platte Bridge Railroad Tragedy
# 356                                                   Purdue Wreck
# 357                                               USS Cole bombing
# 358                                    Pipeline explosion and fire
# 359                                   University of Texas massacre
# 360                                            Dust storm accident
# 361                                         Beltway sniper attacks
# 363                                       La Plata tornado of 1926
# 364                         Waverly, Tennessee, tank car explosion
# 365                                  1987 Maryland train collision
# 366                                             The Dover massacre
# 368                                     2015 San Bernardino attack
# 369                            2016 Lockhart hot air balloon crash
# 370                             March 2017 North American blizzard
# 371                              Cleveland Hill Middle School fire
# 372                                    Edmond post office shooting
# 373                                 Columbine High School massacre
# 374                                     World Wide Tours bus crash
# 375                              West Fertilizer Company explosion
#
#                                               Location  \
# 0                                                Texas
# 1                            San Francisco, California
# 2    New York City, Arlington County, Virginia, and...
# 4                                 Florida, Puerto Rico
# 6                                     Honolulu, Hawaii
# 7                                         Pennsylvania
# 8                                            Louisiana
# 9    Florida, Louisiana, Mississippi, Alabama, Geor...
# 10                 Marion, Arkansas / Helena, Arkansas
# 11                         Central and southern states
# 12    Peshtigo, Wisconsin, Upper Peninsula of Michigan
# 13                       East River near New York City
# 14                             Georgia, South Carolina
# 15                                  Georgetown, Guyana
# 16                                      Philippine Sea
# 17                                   Chicago, Illinois
# 18                                   Chicago, Illinois
# 19   Missouri, Illinois and Indiana(Kentucky, Tenne...
# 21                                   Chicago, Illinois
# 22                                      Florida, Texas
# 23                           Santa Clarita, California
# 24                                                 NaN
# 25                                   Texas City, Texas
# 26                                            Michigan
# 27                               Boston, Massachusetts
# 28                        Gauley Bridge, West Virginia
# 29                                           Minnesota
# 30   Alabama, Arkansas, Mississippi, Georgia, South...
# 31                                                Ohio
# 32              Louisiana, Texas, Mississippi, Alabama
# ..                                                 ...
# 342                            Los Angeles, California
# 343                             Peabody, Massachusetts
# 344                              Boston, Massachusetts
# 346                                 Walker, California
# 347                              Boston, Massachusetts
# 349                 Woodlawn, The Bronx, New York City
# 350                             Lake George (New York)
# 351  Albert Pike Recreation Area near Langley, Arka...
# 352                                 Garrison, New York
# 353                              South Portland, Maine
# 354                                   Yarnell, Arizona
# 355                               St. Joseph, Missouri
# 356                              Indianapolis, Indiana
# 357                                        Aden, Yemen
# 358                            Natchitoches, Louisiana
# 359                                      Austin, Texas
# 360                               Coalinga, California
# 361                       Washington metropolitan area
# 363                                 La Plata, Maryland
# 364                                 Waverly, Tennessee
# 365                                    Chase, Maryland
# 366           Dover, Arkansas - Russellville, Arkansas
# 368                         San Bernardino, California
# 369                                    Lockhart, Texas
# 370  Northeastern United States, Upper Midwest, Gre...
# 371                              Cheektowaga, New York
# 372                                   Edmond, Oklahoma
# 373                         Jefferson County, Colorado
# 374                                    Bronx, New York
# 375                                        West, Texas
#
#                                                   Text
# 0    Fatalities estimated. Remains the deadliest na...
# 1    Conflagration followed quake; fatalities estim...
# 2    2,977 victims and 19 hijackers. Costliest disa...
# 4    4,078 believed dead total. 2500 in Florida, 31...
# 6        2,403 U.S. victims and 64 Japanese attackers.
# 7                 Much rain, deforestation; dam failed
# 8                                 Fatalities estimated
# 9          Costliest natural disaster in U.S. history.
# 10   Steamboat sank due to boiler explosion; fatali...
# 11           Official death toll, may have been higher
# 12   Fatalities estimated; most deaths in single fi...
# 13                 Steamship sank due to fire on board
# 14                                Fatalities estimated
# 15   Cult leader of the Peoples Temple Agricultural...
# 16   Largest loss of life in the history of the U.S...
# 17   Passenger ship capsized in Chicago harbor, cau...
# 18                                                 NaN
# 19   Lower number for single 3-state tornado; highe...
# 21   Worst theater fire in American history; worst ...
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                       Ammonium nitrate onboard ship
# 26                                                 NaN
# 27   Nightclub fire; loss of life due to blocked ex...
# 28   178 admitted deaths, 476 with congressional in...
# 29                                                 NaN
# 30   Two tornadoes in Tupelo, Mississippi, and Gain...
# 31                                                 NaN
# 32                                                 NaN
# ..                                                 ...
# 342                                                NaN
# 343  Schoolgirls trapped behind exit door; resulted...
# 344  Damages are out-of-court settlements only; rep...
# 346                                                NaN
# 347                                                NaN
# 349  The day after the New York Central Railroad in...
# 350  Overloaded tour boat capsized from another boa...
# 351                                                NaN
# 352                                                NaN
# 353                                                NaN
# 354  19 firefighters were killed trapped when they ...
# 355                                                NaN
# 356                                                NaN
# 357                                                NaN
# 358                                                NaN
# 359                                                NaN
# 360                                                NaN
# 361  3 injured in the Beltway sniper attacks and 7 ...
# 363            13 killed in La Plata Elementary School
# 364                           An additional 43 injured
# 365                                                NaN
# 366                                                NaN
# 368                           An additional 24 injured
# 369      Deadliest ballooning disaster in U.S. history
# 370                                                NaN
# 371                                                NaN
# 372                       14 victims and 1 perpetrator
# 373  Armed with 2 sawed-off shotguns, a TEC-9 pisto...
# 374           En route to Connecticut casino, March 12
# 375                 More than 160 people were injured.
#
# [331 rows x 7 columns]

# %%
df['Loss Estimated (US$)'] = df['Loss Estimated (US$)'].apply(lambda x: int(x) if str(x) != '' else x)
# Out:
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
# df['Loss Estimated (US$)'] =df['Loss Estimated (US$)'].apply(lambda x: str(x).replace('$',"")
#                                                                              .replace('(approximate)', "")
#                                                                              .replace(',',"").replace('<',"").replace('>',"")
#                                                                              .replace('-',"").replace('nan',"0").replace("~",""))
# df['Loss Estimated (US$)'] =df['Loss Estimated (US$)'].apply(lambda x: int(x))

# %%
df
# Out:
#      Year                             Cause of Loss           Deaths  \
# 0    1900                          Tropical cyclone  6,000 to 12,000
# 1    1906  Earthquakeand fire (urban conflagration)           3,000+
# 2    2001                                 Terrorism             2996
# 4    1928                          Tropical cyclone             2812
# 6    1941                 Military strike - bombing             2467
# 7    1889                      Accident - Dam burst             2209
# 8    1893                          Tropical cyclone             2000
# 9    2005                          Tropical cyclone             1836
# 10   1865                      Accident - Shipwreck             1700
# 11   1980                                 Heat wave             1700
# 12   1871                              Fire (rural)      1,500-2,500
# 13   1904                      Accident - Shipwreck             1021
# 14   1893                          Tropical cyclone      1,000-2,000
# 15   1978                     Mass murder - suicide              909
# 16   1945                                 Shipwreck              879
# 17   1915                      Accident - Shipwreck              844
# 18   1995                                 Heat wave              739
# 19   1925                                   Tornado          695-747
# 21   1903                           Fire (building)              602
# 22   1919                          Tropical cyclone              600
# 23   1928                    Accident - Dam failure              600
# 24   1938                          Tropical cyclone              600
# 25   1947                      Accident - Explosion              581
# 26   1871                                      Fire  500 (estimated)
# 27   1942                           Fire (building)              492
# 28   1927                   Exploitation, Silicosis       476-1,000+
# 29   1918                              Fire (rural)              453
# 30   1936                          Tornado outbreak             436+
# 31   1913                                     Flood              428
# 32   1957                          Tropical cyclone              416
# ..    ...                                       ...              ...
# 342  1910                                   Bombing               21
# 343  1915                            Fire(building)               21
# 344  1919                      Accident - Explosion               21
# 346  1986                       Accident - tour bus               21
# 347  1872                Fire (urban conflagration)               20
# 349  1907                       Accident - Railroad               20
# 350  2005                      Accident - Shipwreck               20
# 351  2010                                     Flood               20
# 352  1897                       Accident - Railroad               19
# 353  1944                       Accident - Aircraft               19
# 354  2013                                  Wildfire               19
# 355  1861                       Accident - Railroad         17 to 20
# 356  1903                       Accident - Railroad               17
# 357  2000                                 Terrorism               17
# 358  1965            Accidents - Pipeline accidents               17
# 359  1966                               Mass murder               17
# 360  1991                     Accident - Automobile               17
# 361  2002                               Mass murder               17
# 363  1926                                   Tornado               16
# 364  1978                       Accident - Railroad               16
# 365  1987                       Accident - Railroad               16
# 366  1987                               Mass Murder               16
# 368  2015                                 Terrorism               16
# 369  2016                Accident - Hot air balloon               16
# 370  2017                                  blizzard            16-19
# 371  1954                            Fire(building)               15
# 372  1986                               Mass murder               15
# 373  1999                               Mass murder               15
# 374  2011                       Accident - tour bus               15
# 375  2013                      Accident - Explosion               15
#
#     Loss Estimated (US$)                           Cause of Loss.1  \
# 0               28000000                  1900 Galveston hurricane
# 1                                    1906 San Francisco earthquake
# 2           178000000000                      September 11 attacks
# 4              800000000                 1928 Okeechobee hurricane
# 6                                           Attack on Pearl Harbor
# 7                                                  Johnstown Flood
# 8                                 1893 Cheniere Caminada hurricane
# 9           108000000000                         Hurricane Katrina
# 10                                                         Sultana
# 11                                    1980 United States heat wave
# 12                                                   Peshtigo Fire
# 13                                               PS General Slocum
# 14                                      1893 Sea Islands hurricane
# 15                                                       Jonestown
# 16                                             USS Indianapolis[1]
# 17                                                   S.S. Eastland
# 18                                       Chicago Heat Wave of 1995
# 19            1650000000                         Tri-State Tornado
# 21                                           Iroquois Theatre fire
# 22                                     1919 Florida Keys hurricane
# 23                                                 St. Francis Dam
# 24                                      1938 New England hurricane
# 25                                             Texas City disaster
# 26                                             Great Michigan Fire
# 27                                             Cocoanut Grove fire
# 28                                      Hawks Nest Tunnel disaster
# 29               7300000                         1918 Cloquet fire
# 30                        1936 Tupelo–Gainesville tornado outbreak
# 31                                     1913 (Ohio) statewide flood
# 32             147000000                          Hurricane Audrey
# ..                   ...                                       ...
# 342                                       Los Angeles Timesbombing
# 343                                          St. Johns School fire
# 344           6600000000                      Great Molasses Flood
# 346                                                            NaN
# 347             73500000                 Great Boston fire of 1872
# 349                                            Woodlawn derailment
# 350                                    Ethan Allenboating accident
# 351                                      June 2010 Arkansas floods
# 352                                           Garrison train crash
# 353                                        Long Creek air disaster
# 354                                              Yarnell Hill Fire
# 355                                 Platte Bridge Railroad Tragedy
# 356                                                   Purdue Wreck
# 357                                               USS Cole bombing
# 358                                    Pipeline explosion and fire
# 359                                   University of Texas massacre
# 360                                            Dust storm accident
# 361                                         Beltway sniper attacks
# 363                                       La Plata tornado of 1926
# 364                         Waverly, Tennessee, tank car explosion
# 365                                  1987 Maryland train collision
# 366                                             The Dover massacre
# 368                                     2015 San Bernardino attack
# 369                            2016 Lockhart hot air balloon crash
# 370                             March 2017 North American blizzard
# 371                              Cleveland Hill Middle School fire
# 372                                    Edmond post office shooting
# 373                                 Columbine High School massacre
# 374                                     World Wide Tours bus crash
# 375                              West Fertilizer Company explosion
#
#                                               Location  \
# 0                                                Texas
# 1                            San Francisco, California
# 2    New York City, Arlington County, Virginia, and...
# 4                                 Florida, Puerto Rico
# 6                                     Honolulu, Hawaii
# 7                                         Pennsylvania
# 8                                            Louisiana
# 9    Florida, Louisiana, Mississippi, Alabama, Geor...
# 10                 Marion, Arkansas / Helena, Arkansas
# 11                         Central and southern states
# 12    Peshtigo, Wisconsin, Upper Peninsula of Michigan
# 13                       East River near New York City
# 14                             Georgia, South Carolina
# 15                                  Georgetown, Guyana
# 16                                      Philippine Sea
# 17                                   Chicago, Illinois
# 18                                   Chicago, Illinois
# 19   Missouri, Illinois and Indiana(Kentucky, Tenne...
# 21                                   Chicago, Illinois
# 22                                      Florida, Texas
# 23                           Santa Clarita, California
# 24                                                 NaN
# 25                                   Texas City, Texas
# 26                                            Michigan
# 27                               Boston, Massachusetts
# 28                        Gauley Bridge, West Virginia
# 29                                           Minnesota
# 30   Alabama, Arkansas, Mississippi, Georgia, South...
# 31                                                Ohio
# 32              Louisiana, Texas, Mississippi, Alabama
# ..                                                 ...
# 342                            Los Angeles, California
# 343                             Peabody, Massachusetts
# 344                              Boston, Massachusetts
# 346                                 Walker, California
# 347                              Boston, Massachusetts
# 349                 Woodlawn, The Bronx, New York City
# 350                             Lake George (New York)
# 351  Albert Pike Recreation Area near Langley, Arka...
# 352                                 Garrison, New York
# 353                              South Portland, Maine
# 354                                   Yarnell, Arizona
# 355                               St. Joseph, Missouri
# 356                              Indianapolis, Indiana
# 357                                        Aden, Yemen
# 358                            Natchitoches, Louisiana
# 359                                      Austin, Texas
# 360                               Coalinga, California
# 361                       Washington metropolitan area
# 363                                 La Plata, Maryland
# 364                                 Waverly, Tennessee
# 365                                    Chase, Maryland
# 366           Dover, Arkansas - Russellville, Arkansas
# 368                         San Bernardino, California
# 369                                    Lockhart, Texas
# 370  Northeastern United States, Upper Midwest, Gre...
# 371                              Cheektowaga, New York
# 372                                   Edmond, Oklahoma
# 373                         Jefferson County, Colorado
# 374                                    Bronx, New York
# 375                                        West, Texas
#
#                                                   Text
# 0    Fatalities estimated. Remains the deadliest na...
# 1    Conflagration followed quake; fatalities estim...
# 2    2,977 victims and 19 hijackers. Costliest disa...
# 4    4,078 believed dead total. 2500 in Florida, 31...
# 6        2,403 U.S. victims and 64 Japanese attackers.
# 7                 Much rain, deforestation; dam failed
# 8                                 Fatalities estimated
# 9          Costliest natural disaster in U.S. history.
# 10   Steamboat sank due to boiler explosion; fatali...
# 11           Official death toll, may have been higher
# 12   Fatalities estimated; most deaths in single fi...
# 13                 Steamship sank due to fire on board
# 14                                Fatalities estimated
# 15   Cult leader of the Peoples Temple Agricultural...
# 16   Largest loss of life in the history of the U.S...
# 17   Passenger ship capsized in Chicago harbor, cau...
# 18                                                 NaN
# 19   Lower number for single 3-state tornado; highe...
# 21   Worst theater fire in American history; worst ...
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                       Ammonium nitrate onboard ship
# 26                                                 NaN
# 27   Nightclub fire; loss of life due to blocked ex...
# 28   178 admitted deaths, 476 with congressional in...
# 29                                                 NaN
# 30   Two tornadoes in Tupelo, Mississippi, and Gain...
# 31                                                 NaN
# 32                                                 NaN
# ..                                                 ...
# 342                                                NaN
# 343  Schoolgirls trapped behind exit door; resulted...
# 344  Damages are out-of-court settlements only; rep...
# 346                                                NaN
# 347                                                NaN
# 349  The day after the New York Central Railroad in...
# 350  Overloaded tour boat capsized from another boa...
# 351                                                NaN
# 352                                                NaN
# 353                                                NaN
# 354  19 firefighters were killed trapped when they ...
# 355                                                NaN
# 356                                                NaN
# 357                                                NaN
# 358                                                NaN
# 359                                                NaN
# 360                                                NaN
# 361  3 injured in the Beltway sniper attacks and 7 ...
# 363            13 killed in La Plata Elementary School
# 364                           An additional 43 injured
# 365                                                NaN
# 366                                                NaN
# 368                           An additional 24 injured
# 369      Deadliest ballooning disaster in U.S. history
# 370                                                NaN
# 371                                                NaN
# 372                       14 victims and 1 perpetrator
# 373  Armed with 2 sawed-off shotguns, a TEC-9 pisto...
# 374           En route to Connecticut casino, March 12
# 375                 More than 160 people were injured.
#
# [331 rows x 7 columns]

# %%
df['Location'] =df['Location'].apply(lambda x: re.sub(r'\(.*\)', "",str(x)))

# df['Location'] =df['Location'].apply(lambda x: re.findall(r'[A-Z]\w+?\s?\w+$',str(x)))
# df['Location'] =df['Location'].apply(lambda x: re.findall(r'[A-Z]?\w+?\s?[A-Z]?\w+$',str(x)))
# Out:
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df['Location'] =df['Location'].apply(lambda x: re.findall(r'[A-Z]?\w+?\s?\w+$',str(x)))
df['Location'] =df['Location'].apply(lambda x: str(x).replace('[',"").replace(']', "").replace("\'",""))
# Out:
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df
# Out:
#      Year                             Cause of Loss           Deaths  \
# 0    1900                          Tropical cyclone  6,000 to 12,000
# 1    1906  Earthquakeand fire (urban conflagration)           3,000+
# 2    2001                                 Terrorism             2996
# 4    1928                          Tropical cyclone             2812
# 6    1941                 Military strike - bombing             2467
# 7    1889                      Accident - Dam burst             2209
# 8    1893                          Tropical cyclone             2000
# 9    2005                          Tropical cyclone             1836
# 10   1865                      Accident - Shipwreck             1700
# 11   1980                                 Heat wave             1700
# 12   1871                              Fire (rural)      1,500-2,500
# 13   1904                      Accident - Shipwreck             1021
# 14   1893                          Tropical cyclone      1,000-2,000
# 15   1978                     Mass murder - suicide              909
# 16   1945                                 Shipwreck              879
# 17   1915                      Accident - Shipwreck              844
# 18   1995                                 Heat wave              739
# 19   1925                                   Tornado          695-747
# 21   1903                           Fire (building)              602
# 22   1919                          Tropical cyclone              600
# 23   1928                    Accident - Dam failure              600
# 24   1938                          Tropical cyclone              600
# 25   1947                      Accident - Explosion              581
# 26   1871                                      Fire  500 (estimated)
# 27   1942                           Fire (building)              492
# 28   1927                   Exploitation, Silicosis       476-1,000+
# 29   1918                              Fire (rural)              453
# 30   1936                          Tornado outbreak             436+
# 31   1913                                     Flood              428
# 32   1957                          Tropical cyclone              416
# ..    ...                                       ...              ...
# 342  1910                                   Bombing               21
# 343  1915                            Fire(building)               21
# 344  1919                      Accident - Explosion               21
# 346  1986                       Accident - tour bus               21
# 347  1872                Fire (urban conflagration)               20
# 349  1907                       Accident - Railroad               20
# 350  2005                      Accident - Shipwreck               20
# 351  2010                                     Flood               20
# 352  1897                       Accident - Railroad               19
# 353  1944                       Accident - Aircraft               19
# 354  2013                                  Wildfire               19
# 355  1861                       Accident - Railroad         17 to 20
# 356  1903                       Accident - Railroad               17
# 357  2000                                 Terrorism               17
# 358  1965            Accidents - Pipeline accidents               17
# 359  1966                               Mass murder               17
# 360  1991                     Accident - Automobile               17
# 361  2002                               Mass murder               17
# 363  1926                                   Tornado               16
# 364  1978                       Accident - Railroad               16
# 365  1987                       Accident - Railroad               16
# 366  1987                               Mass Murder               16
# 368  2015                                 Terrorism               16
# 369  2016                Accident - Hot air balloon               16
# 370  2017                                  blizzard            16-19
# 371  1954                            Fire(building)               15
# 372  1986                               Mass murder               15
# 373  1999                               Mass murder               15
# 374  2011                       Accident - tour bus               15
# 375  2013                      Accident - Explosion               15
#
#     Loss Estimated (US$)                           Cause of Loss.1  \
# 0               28000000                  1900 Galveston hurricane
# 1                                    1906 San Francisco earthquake
# 2           178000000000                      September 11 attacks
# 4              800000000                 1928 Okeechobee hurricane
# 6                                           Attack on Pearl Harbor
# 7                                                  Johnstown Flood
# 8                                 1893 Cheniere Caminada hurricane
# 9           108000000000                         Hurricane Katrina
# 10                                                         Sultana
# 11                                    1980 United States heat wave
# 12                                                   Peshtigo Fire
# 13                                               PS General Slocum
# 14                                      1893 Sea Islands hurricane
# 15                                                       Jonestown
# 16                                             USS Indianapolis[1]
# 17                                                   S.S. Eastland
# 18                                       Chicago Heat Wave of 1995
# 19            1650000000                         Tri-State Tornado
# 21                                           Iroquois Theatre fire
# 22                                     1919 Florida Keys hurricane
# 23                                                 St. Francis Dam
# 24                                      1938 New England hurricane
# 25                                             Texas City disaster
# 26                                             Great Michigan Fire
# 27                                             Cocoanut Grove fire
# 28                                      Hawks Nest Tunnel disaster
# 29               7300000                         1918 Cloquet fire
# 30                        1936 Tupelo–Gainesville tornado outbreak
# 31                                     1913 (Ohio) statewide flood
# 32             147000000                          Hurricane Audrey
# ..                   ...                                       ...
# 342                                       Los Angeles Timesbombing
# 343                                          St. Johns School fire
# 344           6600000000                      Great Molasses Flood
# 346                                                            NaN
# 347             73500000                 Great Boston fire of 1872
# 349                                            Woodlawn derailment
# 350                                    Ethan Allenboating accident
# 351                                      June 2010 Arkansas floods
# 352                                           Garrison train crash
# 353                                        Long Creek air disaster
# 354                                              Yarnell Hill Fire
# 355                                 Platte Bridge Railroad Tragedy
# 356                                                   Purdue Wreck
# 357                                               USS Cole bombing
# 358                                    Pipeline explosion and fire
# 359                                   University of Texas massacre
# 360                                            Dust storm accident
# 361                                         Beltway sniper attacks
# 363                                       La Plata tornado of 1926
# 364                         Waverly, Tennessee, tank car explosion
# 365                                  1987 Maryland train collision
# 366                                             The Dover massacre
# 368                                     2015 San Bernardino attack
# 369                            2016 Lockhart hot air balloon crash
# 370                             March 2017 North American blizzard
# 371                              Cleveland Hill Middle School fire
# 372                                    Edmond post office shooting
# 373                                 Columbine High School massacre
# 374                                     World Wide Tours bus crash
# 375                              West Fertilizer Company explosion
#
#               Location                                               Text
# 0                Texas  Fatalities estimated. Remains the deadliest na...
# 1           California  Conflagration followed quake; fatalities estim...
# 2         Pennsylvania  2,977 victims and 19 hijackers. Costliest disa...
# 4          Puerto Rico  4,078 believed dead total. 2500 in Florida, 31...
# 6               Hawaii      2,403 U.S. victims and 64 Japanese attackers.
# 7         Pennsylvania               Much rain, deforestation; dam failed
# 8            Louisiana                               Fatalities estimated
# 9          and\xa0Ohio        Costliest natural disaster in U.S. history.
# 10            Arkansas  Steamboat sank due to boiler explosion; fatali...
# 11     southern states          Official death toll, may have been higher
# 12         of Michigan  Fatalities estimated; most deaths in single fi...
# 13           York City                Steamship sank due to fire on board
# 14      South Carolina                               Fatalities estimated
# 15              Guyana  Cult leader of the Peoples Temple Agricultural...
# 16      Philippine Sea  Largest loss of life in the history of the U.S...
# 17            Illinois  Passenger ship capsized in Chicago harbor, cau...
# 18            Illinois                                                NaN
# 19      and\xa0Indiana  Lower number for single 3-state tornado; highe...
# 21            Illinois  Worst theater fire in American history; worst ...
# 22               Texas                                                NaN
# 23          California                                                NaN
# 24                 nan                                                NaN
# 25               Texas                      Ammonium nitrate onboard ship
# 26            Michigan                                                NaN
# 27       Massachusetts  Nightclub fire; loss of life due to blocked ex...
# 28       West Virginia  178 admitted deaths, 476 with congressional in...
# 29           Minnesota                                                NaN
# 30           Tennessee  Two tornadoes in Tupelo, Mississippi, and Gain...
# 31                Ohio                                                NaN
# 32             Alabama                                                NaN
# ..                 ...                                                ...
# 342         California                                                NaN
# 343      Massachusetts  Schoolgirls trapped behind exit door; resulted...
# 344      Massachusetts  Damages are out-of-court settlements only; rep...
# 346         California                                                NaN
# 347      Massachusetts                                                NaN
# 349          York City  The day after the New York Central Railroad in...
# 350                     Overloaded tour boat capsized from another boa...
# 351           Arkansas                                                NaN
# 352           New York                                                NaN
# 353              Maine                                                NaN
# 354            Arizona  19 firefighters were killed trapped when they ...
# 355           Missouri                                                NaN
# 356            Indiana                                                NaN
# 357              Yemen                                                NaN
# 358          Louisiana                                                NaN
# 359              Texas                                                NaN
# 360         California                                                NaN
# 361  metropolitan area  3 injured in the Beltway sniper attacks and 7 ...
# 363           Maryland            13 killed in La Plata Elementary School
# 364          Tennessee                           An additional 43 injured
# 365           Maryland                                                NaN
# 366           Arkansas                                                NaN
# 368         California                           An additional 24 injured
# 369              Texas      Deadliest ballooning disaster in U.S. history
# 370       Great Plains                                                NaN
# 371           New York                                                NaN
# 372           Oklahoma                       14 victims and 1 perpetrator
# 373           Colorado  Armed with 2 sawed-off shotguns, a TEC-9 pisto...
# 374           New York           En route to Connecticut casino, March 12
# 375              Texas                 More than 160 people were injured.
#
# [331 rows x 7 columns]

# %%
df.drop(labels='Cause of Loss.1',axis=1, inplace=True)
# Out:
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df.insert(1, 'Country', value='USA')

# %%
df
# Out:
#      Year Country                             Cause of Loss           Deaths  \
# 0    1900     USA                          Tropical cyclone  6,000 to 12,000
# 1    1906     USA  Earthquakeand fire (urban conflagration)           3,000+
# 2    2001     USA                                 Terrorism             2996
# 4    1928     USA                          Tropical cyclone             2812
# 6    1941     USA                 Military strike - bombing             2467
# 7    1889     USA                      Accident - Dam burst             2209
# 8    1893     USA                          Tropical cyclone             2000
# 9    2005     USA                          Tropical cyclone             1836
# 10   1865     USA                      Accident - Shipwreck             1700
# 11   1980     USA                                 Heat wave             1700
# 12   1871     USA                              Fire (rural)      1,500-2,500
# 13   1904     USA                      Accident - Shipwreck             1021
# 14   1893     USA                          Tropical cyclone      1,000-2,000
# 15   1978     USA                     Mass murder - suicide              909
# 16   1945     USA                                 Shipwreck              879
# 17   1915     USA                      Accident - Shipwreck              844
# 18   1995     USA                                 Heat wave              739
# 19   1925     USA                                   Tornado          695-747
# 21   1903     USA                           Fire (building)              602
# 22   1919     USA                          Tropical cyclone              600
# 23   1928     USA                    Accident - Dam failure              600
# 24   1938     USA                          Tropical cyclone              600
# 25   1947     USA                      Accident - Explosion              581
# 26   1871     USA                                      Fire  500 (estimated)
# 27   1942     USA                           Fire (building)              492
# 28   1927     USA                   Exploitation, Silicosis       476-1,000+
# 29   1918     USA                              Fire (rural)              453
# 30   1936     USA                          Tornado outbreak             436+
# 31   1913     USA                                     Flood              428
# 32   1957     USA                          Tropical cyclone              416
# ..    ...     ...                                       ...              ...
# 342  1910     USA                                   Bombing               21
# 343  1915     USA                            Fire(building)               21
# 344  1919     USA                      Accident - Explosion               21
# 346  1986     USA                       Accident - tour bus               21
# 347  1872     USA                Fire (urban conflagration)               20
# 349  1907     USA                       Accident - Railroad               20
# 350  2005     USA                      Accident - Shipwreck               20
# 351  2010     USA                                     Flood               20
# 352  1897     USA                       Accident - Railroad               19
# 353  1944     USA                       Accident - Aircraft               19
# 354  2013     USA                                  Wildfire               19
# 355  1861     USA                       Accident - Railroad         17 to 20
# 356  1903     USA                       Accident - Railroad               17
# 357  2000     USA                                 Terrorism               17
# 358  1965     USA            Accidents - Pipeline accidents               17
# 359  1966     USA                               Mass murder               17
# 360  1991     USA                     Accident - Automobile               17
# 361  2002     USA                               Mass murder               17
# 363  1926     USA                                   Tornado               16
# 364  1978     USA                       Accident - Railroad               16
# 365  1987     USA                       Accident - Railroad               16
# 366  1987     USA                               Mass Murder               16
# 368  2015     USA                                 Terrorism               16
# 369  2016     USA                Accident - Hot air balloon               16
# 370  2017     USA                                  blizzard            16-19
# 371  1954     USA                            Fire(building)               15
# 372  1986     USA                               Mass murder               15
# 373  1999     USA                               Mass murder               15
# 374  2011     USA                       Accident - tour bus               15
# 375  2013     USA                      Accident - Explosion               15
#
#     Loss Estimated (US$)           Location  \
# 0               28000000              Texas
# 1                                California
# 2           178000000000       Pennsylvania
# 4              800000000        Puerto Rico
# 6                                    Hawaii
# 7                              Pennsylvania
# 8                                 Louisiana
# 9           108000000000        and\xa0Ohio
# 10                                 Arkansas
# 11                          southern states
# 12                              of Michigan
# 13                                York City
# 14                           South Carolina
# 15                                   Guyana
# 16                           Philippine Sea
# 17                                 Illinois
# 18                                 Illinois
# 19            1650000000     and\xa0Indiana
# 21                                 Illinois
# 22                                    Texas
# 23                               California
# 24                                      nan
# 25                                    Texas
# 26                                 Michigan
# 27                            Massachusetts
# 28                            West Virginia
# 29               7300000          Minnesota
# 30                                Tennessee
# 31                                     Ohio
# 32             147000000            Alabama
# ..                   ...                ...
# 342                              California
# 343                           Massachusetts
# 344           6600000000      Massachusetts
# 346                              California
# 347             73500000      Massachusetts
# 349                               York City
# 350
# 351                                Arkansas
# 352                                New York
# 353                                   Maine
# 354                                 Arizona
# 355                                Missouri
# 356                                 Indiana
# 357                                   Yemen
# 358                               Louisiana
# 359                                   Texas
# 360                              California
# 361                       metropolitan area
# 363                                Maryland
# 364                               Tennessee
# 365                                Maryland
# 366                                Arkansas
# 368                              California
# 369                                   Texas
# 370                            Great Plains
# 371                                New York
# 372                                Oklahoma
# 373                                Colorado
# 374                                New York
# 375                                   Texas
#
#                                                   Text
# 0    Fatalities estimated. Remains the deadliest na...
# 1    Conflagration followed quake; fatalities estim...
# 2    2,977 victims and 19 hijackers. Costliest disa...
# 4    4,078 believed dead total. 2500 in Florida, 31...
# 6        2,403 U.S. victims and 64 Japanese attackers.
# 7                 Much rain, deforestation; dam failed
# 8                                 Fatalities estimated
# 9          Costliest natural disaster in U.S. history.
# 10   Steamboat sank due to boiler explosion; fatali...
# 11           Official death toll, may have been higher
# 12   Fatalities estimated; most deaths in single fi...
# 13                 Steamship sank due to fire on board
# 14                                Fatalities estimated
# 15   Cult leader of the Peoples Temple Agricultural...
# 16   Largest loss of life in the history of the U.S...
# 17   Passenger ship capsized in Chicago harbor, cau...
# 18                                                 NaN
# 19   Lower number for single 3-state tornado; highe...
# 21   Worst theater fire in American history; worst ...
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                       Ammonium nitrate onboard ship
# 26                                                 NaN
# 27   Nightclub fire; loss of life due to blocked ex...
# 28   178 admitted deaths, 476 with congressional in...
# 29                                                 NaN
# 30   Two tornadoes in Tupelo, Mississippi, and Gain...
# 31                                                 NaN
# 32                                                 NaN
# ..                                                 ...
# 342                                                NaN
# 343  Schoolgirls trapped behind exit door; resulted...
# 344  Damages are out-of-court settlements only; rep...
# 346                                                NaN
# 347                                                NaN
# 349  The day after the New York Central Railroad in...
# 350  Overloaded tour boat capsized from another boa...
# 351                                                NaN
# 352                                                NaN
# 353                                                NaN
# 354  19 firefighters were killed trapped when they ...
# 355                                                NaN
# 356                                                NaN
# 357                                                NaN
# 358                                                NaN
# 359                                                NaN
# 360                                                NaN
# 361  3 injured in the Beltway sniper attacks and 7 ...
# 363            13 killed in La Plata Elementary School
# 364                           An additional 43 injured
# 365                                                NaN
# 366                                                NaN
# 368                           An additional 24 injured
# 369      Deadliest ballooning disaster in U.S. history
# 370                                                NaN
# 371                                                NaN
# 372                       14 victims and 1 perpetrator
# 373  Armed with 2 sawed-off shotguns, a TEC-9 pisto...
# 374           En route to Connecticut casino, March 12
# 375                 More than 160 people were injured.
#
# [331 rows x 7 columns]

# %%
df['Source'] = 'https://en.wikipedia.org/wiki/List_of_disasters_in_the_United_States_by_death_toll'
# Out:
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df['Year'] = df['Year'].apply(lambda x: int(x))
# Out:
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df.sort_values(['Year'], inplace=True)
# Out:
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df.tail(10)
# Out:
#      Year Country               Cause of Loss Deaths Loss Estimated (US$)  \
# 285  2015     USA        Accident - Shipwreck     33
# 368  2015     USA                   Terrorism     16
# 280  2016     USA              Fire(building)     36
# 252  2016     USA            Tropical cyclone     47          10000000000
# 369  2016     USA  Accident - Hot air balloon     16
# 235  2016     USA                   Terrorism     50
# 219  2016     USA                    Blizzard     55            500000000
# 277  2017     USA            Tropical cyclone     38          50000000000
# 370  2017     USA                    blizzard  16-19
# 170  2017     USA            Tropical cyclone     82          70000000000
#
#            Location                                               Text  \
# 285  the\xa0Bahamas  A U.S.-flagged vessel sank during Hurricane Jo...
# 368      California                           An additional 24 injured
# 280      California                                                NaN
# 252   The Carolinas  Damage and death figures are for the U.S. only...
# 369           Texas      Deadliest ballooning disaster in U.S. history
# 235         Florida  49 victims and 1 perpetrator. Deadliest shooti...
# 219   United States                                                NaN
# 277   United States  Damage and death figures are for the U.S. only...
# 370    Great Plains                                                NaN
# 170       Louisiana                     One additional death in Guyana
#
#                                                 Source
# 285  https://en.wikipedia.org/wiki/List_of_disaster...
# 368  https://en.wikipedia.org/wiki/List_of_disaster...
# 280  https://en.wikipedia.org/wiki/List_of_disaster...
# 252  https://en.wikipedia.org/wiki/List_of_disaster...
# 369  https://en.wikipedia.org/wiki/List_of_disaster...
# 235  https://en.wikipedia.org/wiki/List_of_disaster...
# 219  https://en.wikipedia.org/wiki/List_of_disaster...
# 277  https://en.wikipedia.org/wiki/List_of_disaster...
# 370  https://en.wikipedia.org/wiki/List_of_disaster...
# 170  https://en.wikipedia.org/wiki/List_of_disaster...

# %%
writer = pd.ExcelWriter('US_disasters_by_death_toll_1837_2017.xlsx')
df.to_excel(writer,'USA_death_toll1837to2017')
writer.save()
