# %%
import pandas as pd
import re

# %% [markdown]
# ## Gas Distribution: 1986 - feb 2004

# %%
file = "sources_from_links/PHMSA_Pipeline_Safety_Flagged_Incidents/gd1986tofeb2004.xlsx"

# %%
data = pd.read_excel(file, sheetname="gd1986tofeb2004")

# %%
data.head()
# Out:
#        DATAFILE_AS_OF SIGNIFICANT SERIOUS     RPTID DOR   OPID  \
# 0 2017-08-31 08:48:03         YES     YES  19860018 NaT  13710
# 1 2017-08-31 08:48:03         YES      NO  19860022 NaT   8160
# 2 2017-08-31 08:48:03          NO      NO  19860023 NaT  13360
# 3 2017-08-31 08:48:03         YES     YES  19860028 NaT  13840
# 4 2017-08-31 08:48:03          NO      NO  19860030 NaT   3500
#
#                                NAME                              INADR  \
# 0          NORTHERN ILLINOIS GAS CO                     15 WEST MONROE
# 1              INTERMOUNTAIN GAS CO                   1925 SHOSHONE ST
# 2    NEW ORLEANS PUBLIC SERVICE INC                    2509 TULANE AVE
# 3          NORTHWEST NATURAL GAS CO           1017 NORTH EAST BEECH ST
# 4  DOUBLE SPRINGS NATURAL GAS BOARD  HGWY 195 NORTH AND CHICKENFOOT RD
#
#          ACCTY      ACCNT                        ...                          \
# 0   VILLA PARK    DU PAGE                        ...
# 1        BOISE        ADA                        ...
# 2  NEW ORLEANS    ORLEANS                        ...
# 3     PORTLAND  MULTNOMAH                        ...
# 4                 WINSTON                        ...
#
#                       DMGO NOTIF  NOTDT  MARK MRKTP MRKTO  STAT  \
# 0                           Null    NaT  Null   NaN        Null
# 1                    FROST    NO    NaT    NO   0.0          NO
# 2  EXPANSION & CONTRACTION    NO    NaT    NO   0.0          NO
# 3                           Null    NaT  Null   NaN        Null
# 4                             NO    NaT    NO   0.0         YES
#
#                                       CAULC  CAULO  \
# 0  ERROR IN OPERATING PROCEDURE APPLICATION
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#                                            NARRATIVE
# 0                                                NaN
# 1                                                NaN
# 2  BROKEN 6" CAST IRON MAIN - GAS MIGRATED THROUG...
# 3  THE BLAST DESTROYED THIS HOME AND DID MAJOR DA...
# 4  PART D - THE STATE HIGHWAY DEPT. WAS INSTALLIN...
#
# [5 rows x 68 columns]

# %%
df = pd.DataFrame(data=data, columns=['IDATE','ACCST', 'CAUSE',
                                      'NAME', 'NARRATIVE', 'TOTAL_COST'])

# %%
df.head(10)
# Out:
#        IDATE ACCST                            CAUSE  \
# 0 1986-01-02    IL     CONSTRUCTION/OPERATING ERROR
# 1 1986-01-13    ID         DAMAGE BY OUTSIDE FORCES
# 2 1986-01-13    LA         DAMAGE BY OUTSIDE FORCES
# 3 1986-01-01    OR                            OTHER
# 4 1986-01-10    AL         DAMAGE BY OUTSIDE FORCES
# 5 1986-01-27    IL         DAMAGE BY OUTSIDE FORCES
# 6 1986-01-11    MA                            OTHER
# 7 1986-02-04    MS         DAMAGE BY OUTSIDE FORCES
# 8 1986-01-05    MA         DAMAGE BY OUTSIDE FORCES
# 9 1986-01-13    TX  ACCIDENTALLY CAUSED BY OPERATOR
#
#                                     NAME  \
# 0               NORTHERN ILLINOIS GAS CO
# 1                   INTERMOUNTAIN GAS CO
# 2         NEW ORLEANS PUBLIC SERVICE INC
# 3               NORTHWEST NATURAL GAS CO
# 4       DOUBLE SPRINGS NATURAL GAS BOARD
# 5               NORTHERN ILLINOIS GAS CO
# 6                       BAY STATE GAS CO
# 7                              ENTEX INC
# 8                          BOSTON GAS CO
# 9  SAN ANTONIO CITY PUBLIC SERVICE BOARD
#
#                                            NARRATIVE  TOTAL_COST
# 0                                                NaN           0
# 1                                                NaN       55000
# 2  BROKEN 6" CAST IRON MAIN - GAS MIGRATED THROUG...           0
# 3  THE BLAST DESTROYED THIS HOME AND DID MAJOR DA...      800000
# 4  PART D - THE STATE HIGHWAY DEPT. WAS INSTALLIN...           0
# 5  DURING THE YEAR OF 1985 A INSTALLING UNDER GRO...      150000
# 6  FIRE IS UNDER INVESTIGATION BY STATE AUTHORITI...      500000
# 7  1/2" PLASTIC SERVICE LIEN WAS CUT APPROXIMATEL...      250000
# 8  INVESTIGATION FOUND BROKEN 6" CAST IRON MAIN I...      200000
# 9  OPERATOR'S EMPLOYEE VIOLATED SAFETY PROCEDURES...           0

# %%
df.CAUSE.value_counts()
# Out:
# DAMAGE BY OUTSIDE FORCES           1442
# OTHER                               644
# CONSTRUCTION/OPERATING ERROR        145
# ACCIDENTALLY CAUSED BY OPERATOR     108
# CORROSION                            87
# NO DATA                               9
# Name: CAUSE, dtype: int64

# %%
df['CAUSE'][df.CAUSE == "DAMAGE BY OUTSIDE FORCES"] = 'other'
df['CAUSE'][df.CAUSE == "OTHER"] = 'other'
df['CAUSE'][df.CAUSE == "CONSTRUCTION/OPERATING ERROR"] = 'technical failure'
df['CAUSE'][df.CAUSE == "ACCIDENTALLY CAUSED BY OPERATOR"] = 'sabotage'
df['CAUSE'][df.CAUSE == "NO DATA"] = ''
df['CAUSE'][df.CAUSE == "CORROSION"] = 'maintenance'
# df['CAUSE'][df.CAUSE == "MATERIAL AND/OR WELD FAILURES"] = 'leaks and spills'
# df['CAUSE'][df.CAUSE == "NATURAL FORCES"] = 'natural disasters'
# df['CAUSE'][df.CAUSE == "EQUIPMENT"] = 'maintenance'


# df['CAUSE'][df.CAUSE == "NATURAL FORCE DAMAGE"] = 'natural disasters'
# Out:
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df.rename(columns = {'IDATE'  :'Incident Date',
                     'NAME'   : 'Name of Owner',
                     'ACCST': 'State',
                     'CAUSE'   : 'Cause of Loss', 
                     'NARRATIVE'  : 'Text',
                     'TOTAL_COST'  : 'Total Gas Released ($)'},
                      inplace = True)

# %%
df.insert(3, column='Name of Installation', value=data.ACCNT.values.astype(str))

df['Name of Installation'] = 'UNKNOWN (' + df['Name of Installation'] + ' COUNTY)'

# df['Incident Date'] =  pd.to_datetime(df['Incident Date'], format='%m/%d/%Y')

df['Total Gas Released ($)'] = df['Total Gas Released ($)'].fillna('').astype(str)

# %%
df['Sources'] = "https://www.phmsa.dot.gov/pipeline/library/data-stats/flagged-data-files"

# %%
df.head(10)
# Out:
#   Incident Date State      Cause of Loss          Name of Installation  \
# 0    1986-01-02    IL  technical failure      UNKNOWN (DU PAGE COUNTY)
# 1    1986-01-13    ID              other          UNKNOWN (ADA COUNTY)
# 2    1986-01-13    LA              other      UNKNOWN (ORLEANS COUNTY)
# 3    1986-01-01    OR              other    UNKNOWN (MULTNOMAH COUNTY)
# 4    1986-01-10    AL              other      UNKNOWN (WINSTON COUNTY)
# 5    1986-01-27    IL              other         UNKNOWN (COOK COUNTY)
# 6    1986-01-11    MA              other        UNKNOWN (ESSEX COUNTY)
# 7    1986-02-04    MS              other       UNKNOWN (COPIAH COUNTY)
# 8    1986-01-05    MA              other  UNKNOWN (EAST BOSTON COUNTY)
# 9    1986-01-13    TX           sabotage        UNKNOWN (BEXAR COUNTY)
#
#                            Name of Owner  \
# 0               NORTHERN ILLINOIS GAS CO
# 1                   INTERMOUNTAIN GAS CO
# 2         NEW ORLEANS PUBLIC SERVICE INC
# 3               NORTHWEST NATURAL GAS CO
# 4       DOUBLE SPRINGS NATURAL GAS BOARD
# 5               NORTHERN ILLINOIS GAS CO
# 6                       BAY STATE GAS CO
# 7                              ENTEX INC
# 8                          BOSTON GAS CO
# 9  SAN ANTONIO CITY PUBLIC SERVICE BOARD
#
#                                                 Text Total Gas Released ($)  \
# 0                                                NaN                      0
# 1                                                NaN                  55000
# 2  BROKEN 6" CAST IRON MAIN - GAS MIGRATED THROUG...                      0
# 3  THE BLAST DESTROYED THIS HOME AND DID MAJOR DA...                 800000
# 4  PART D - THE STATE HIGHWAY DEPT. WAS INSTALLIN...                      0
# 5  DURING THE YEAR OF 1985 A INSTALLING UNDER GRO...                 150000
# 6  FIRE IS UNDER INVESTIGATION BY STATE AUTHORITI...                 500000
# 7  1/2" PLASTIC SERVICE LIEN WAS CUT APPROXIMATEL...                 250000
# 8  INVESTIGATION FOUND BROKEN 6" CAST IRON MAIN I...                 200000
# 9  OPERATOR'S EMPLOYEE VIOLATED SAFETY PROCEDURES...                      0
#
#                                              Sources
# 0  https://www.phmsa.dot.gov/pipeline/library/dat...
# 1  https://www.phmsa.dot.gov/pipeline/library/dat...
# 2  https://www.phmsa.dot.gov/pipeline/library/dat...
# 3  https://www.phmsa.dot.gov/pipeline/library/dat...
# 4  https://www.phmsa.dot.gov/pipeline/library/dat...
# 5  https://www.phmsa.dot.gov/pipeline/library/dat...
# 6  https://www.phmsa.dot.gov/pipeline/library/dat...
# 7  https://www.phmsa.dot.gov/pipeline/library/dat...
# 8  https://www.phmsa.dot.gov/pipeline/library/dat...
# 9  https://www.phmsa.dot.gov/pipeline/library/dat...

# %%
writer = pd.ExcelWriter('gas_distribution_1986_to_feb_2004.xlsx')
df.to_excel(writer,'gd1986tofeb2004')
writer.save()

# %% [markdown]
# ## gas distribution: 2010 - Present

# %%
file2 = "sources_from_links/PHMSA_Pipeline_Safety_Flagged_Incidents/gd2010toPresent.xlsx"

# %%
data2 = pd.read_excel(file2, sheetname="gd2010toPresent")

# %%
df2 = pd.DataFrame(data=data2, columns=['LOCAL_DATETIME','OPERATOR_STATE_ABBREVIATION', 'CAUSE','NAME', 'NARRATIVE', 'EST_COST_GAS_RELEASED'])

# %%
df2
# Out:
#          LOCAL_DATETIME OPERATOR_STATE_ABBREVIATION  \
# 0   2010-02-13 23:35:00                          CA
# 1   2010-02-16 10:38:00                          IN
# 2   2010-02-22 20:57:00                          AZ
# 3   2010-02-18 19:05:00                          IL
# 4   2010-02-21 01:38:00                          NM
# 5   2010-02-01 10:07:00                          MN
# 6   2010-01-29 23:55:00                          AL
# 7   2010-02-26 14:17:00                          IL
# 8   2010-02-17 11:45:00                          TX
# 9   2010-02-25 19:37:00                          UT
# 10  2010-03-01 10:56:00                          GA
# 11  2010-01-18 04:38:00                          NJ
# 12  2010-01-12 20:53:00                          IL
# 13  2010-02-05 11:58:00                          VA
# 14  2010-03-25 15:38:00                          NM
# 15  2010-02-23 12:35:00                          MN
# 16  2010-04-06 13:45:00                          AK
# 17  2010-04-05 16:08:00                          OH
# 18  2010-04-09 13:30:00                          NJ
# 19  2010-01-09 16:27:00                          CA
# 20  2010-02-07 16:27:00                          CA
# 21  2010-01-25 14:30:00                          OH
# 22  2010-04-13 04:45:00                          MN
# 23  2010-04-12 16:20:00                          KY
# 24  2010-04-19 10:58:00                          NJ
# 25  2010-05-11 12:05:00                          SC
# 26  2010-04-26 11:30:00                          PA
# 27  2010-04-29 17:43:00                          DC
# 28  2010-05-06 13:52:00                          SD
# 29  2010-05-09 20:42:00                          KY
# ..                  ...                         ...
# 794 2017-04-25 15:41:00                          MO
# 795 2017-05-05 01:20:00                          NV
# 796 2017-03-17 00:55:00                          DC
# 797 2017-05-12 16:30:00                          NE
# 798 2017-05-15 10:55:00                          GA
# 799 2017-05-08 13:55:00                          CA
# 800 2017-04-06 20:47:00                          IN
# 801 2017-05-23 06:55:00                          CO
# 802 2017-05-25 08:31:00                          IL
# 803 2017-06-07 01:58:00                          NV
# 804 2017-06-09 09:54:00                          MO
# 805 2017-06-12 14:40:00                          WA
# 806 2017-06-21 05:08:00                          CO
# 807 2017-06-22 08:09:00                          MA
# 808 2017-06-22 12:50:00                          IN
# 809 2017-07-07 03:16:00                          NV
# 810 2017-06-20 19:23:00                          CA
# 811 2017-07-07 19:00:00                          NJ
# 812 2017-06-28 16:53:00                          KY
# 813 2017-07-02 12:39:00                          PA
# 814 2017-07-03 08:42:00                          CA
# 815 2017-07-03 23:06:00                          CA
# 816 2017-07-22 23:50:00                          KS
# 817 2017-07-10 14:58:00                          MA
# 818 2017-07-08 11:15:00                          CA
# 819 2017-07-21 09:11:00                          CA
# 820 2017-07-26 14:18:00                          CA
# 821 2017-07-27 14:01:00                          CA
# 822 2017-07-28 15:59:00                          MI
# 823 2017-08-01 14:06:00                          GA
#
#                                 CAUSE  \
# 0          OTHER OUTSIDE FORCE DAMAGE
# 1                   EXCAVATION DAMAGE
# 2                NATURAL FORCE DAMAGE
# 3                   CORROSION FAILURE
# 4          OTHER OUTSIDE FORCE DAMAGE
# 5          OTHER OUTSIDE FORCE DAMAGE
# 6          OTHER OUTSIDE FORCE DAMAGE
# 7                NATURAL FORCE DAMAGE
# 8          OTHER OUTSIDE FORCE DAMAGE
# 9          OTHER OUTSIDE FORCE DAMAGE
# 10                  EQUIPMENT FAILURE
# 11               NATURAL FORCE DAMAGE
# 12   MATERIAL FAILURE OF PIPE OR WELD
# 13         OTHER OUTSIDE FORCE DAMAGE
# 14         OTHER OUTSIDE FORCE DAMAGE
# 15                  EXCAVATION DAMAGE
# 16         OTHER OUTSIDE FORCE DAMAGE
# 17                INCORRECT OPERATION
# 18                  EXCAVATION DAMAGE
# 19               NATURAL FORCE DAMAGE
# 20         OTHER OUTSIDE FORCE DAMAGE
# 21         OTHER OUTSIDE FORCE DAMAGE
# 22               NATURAL FORCE DAMAGE
# 23         OTHER OUTSIDE FORCE DAMAGE
# 24                  EXCAVATION DAMAGE
# 25               OTHER INCIDENT CAUSE
# 26                  EXCAVATION DAMAGE
# 27         OTHER OUTSIDE FORCE DAMAGE
# 28                  EXCAVATION DAMAGE
# 29         OTHER OUTSIDE FORCE DAMAGE
# ..                                ...
# 794                 EXCAVATION DAMAGE
# 795        OTHER OUTSIDE FORCE DAMAGE
# 796        OTHER OUTSIDE FORCE DAMAGE
# 797                 EXCAVATION DAMAGE
# 798        OTHER OUTSIDE FORCE DAMAGE
# 799  MATERIAL FAILURE OF PIPE OR WELD
# 800        OTHER OUTSIDE FORCE DAMAGE
# 801              OTHER INCIDENT CAUSE
# 802                 EXCAVATION DAMAGE
# 803        OTHER OUTSIDE FORCE DAMAGE
# 804                 EXCAVATION DAMAGE
# 805              OTHER INCIDENT CAUSE
# 806        OTHER OUTSIDE FORCE DAMAGE
# 807        OTHER OUTSIDE FORCE DAMAGE
# 808                 EXCAVATION DAMAGE
# 809        OTHER OUTSIDE FORCE DAMAGE
# 810                 EXCAVATION DAMAGE
# 811              NATURAL FORCE DAMAGE
# 812              OTHER INCIDENT CAUSE
# 813              OTHER INCIDENT CAUSE
# 814                 EXCAVATION DAMAGE
# 815        OTHER OUTSIDE FORCE DAMAGE
# 816              NATURAL FORCE DAMAGE
# 817                 EXCAVATION DAMAGE
# 818                 EXCAVATION DAMAGE
# 819                 EXCAVATION DAMAGE
# 820        OTHER OUTSIDE FORCE DAMAGE
# 821                 EXCAVATION DAMAGE
# 822        OTHER OUTSIDE FORCE DAMAGE
# 823                 EXCAVATION DAMAGE
#
#                                                   NAME  \
# 0                            PACIFIC GAS & ELECTRIC CO
# 1                   NORTHERN INDIANA PUBLIC SERVICE CO
# 2                            UNISOURCE ENERGY SERVICES
# 3                             NORTHERN ILLINOIS GAS CO
# 4                               NEW MEXICO GAS COMPANY
# 5                NORTHERN STATES POWER CO OF MINNESOTA
# 6                           FLORENCE GAS DEPT, CITY OF
# 7                                             AMERENIP
# 8                         THE NATURAL GAS COMPANY, LLC
# 9                                  QUESTAR GAS COMPANY
# 10                                    FLORIDA CITY GAS
# 11                    PUBLIC SERVICE ELECTRIC & GAS CO
# 12                            NORTHERN ILLINOIS GAS CO
# 13                                   RICHMOND, CITY OF
# 14                         LOS ALAMOS COUNTY UTILITIES
# 15   CENTERPOINT ENERGY RESOURCES CORP., DBA CENTER...
# 16                               ENSTAR NATURAL GAS CO
# 17                                    DUKE ENERGY OHIO
# 18                    PUBLIC SERVICE ELECTRIC & GAS CO
# 19                           PACIFIC GAS & ELECTRIC CO
# 20                           PACIFIC GAS & ELECTRIC CO
# 21                                  DOMINION EAST OHIO
# 22   CENTERPOINT ENERGY RESOURCES CORP., DBA CENTER...
# 23                        LOUISVILLE GAS & ELECTRIC CO
# 24                    PUBLIC SERVICE ELECTRIC & GAS CO
# 25                    SOUTH CAROLINA ELECTRIC & GAS CO
# 26                                      PECO ENERGY CO
# 27                             WASHINGTON GAS LIGHT CO
# 28                             NORTHWESTERN ENERGY LLC
# 29                        LOUISVILLE GAS & ELECTRIC CO
# ..                                                 ...
# 794                                     LACLEDE GAS CO
# 795                                 SOUTHWEST GAS CORP
# 796                            WASHINGTON GAS LIGHT CO
# 797                                 BLACK HILLS ENERGY
# 798  LIBERTY ENERGY (GEORGIA) CORP D/B/A LIBERTY UT...
# 799                         SOUTHERN CALIFORNIA GAS CO
# 800                                 INDIANA GAS CO INC
# 801                      PUBLIC SERVICE CO OF COLORADO
# 802                        PEOPLES GAS LIGHT & COKE CO
# 803                                 SOUTHWEST GAS CORP
# 804                                MISSOURI GAS ENERGY
# 805                                 PUGET SOUND ENERGY
# 806                      PUBLIC SERVICE CO OF COLORADO
# 807                      COLUMBIA GAS OF MASSACHUSETTS
# 808                    VECTREN ENERGY DELIVERY OF OHIO
# 809                                 SOUTHWEST GAS CORP
# 810                         SOUTHERN CALIFORNIA GAS CO
# 811                   PUBLIC SERVICE ELECTRIC & GAS CO
# 812                          MURRAY NATURAL GAS SYSTEM
# 813                                 UGI UTILITIES, INC
# 814                          PACIFIC GAS & ELECTRIC CO
# 815                         SOUTHERN CALIFORNIA GAS CO
# 816  KANSAS GAS SERVICE COMPANY, A DIVISION OF ONE ...
# 817                          NIAGARA MOHAWK POWER CORP
# 818                         SOUTHERN CALIFORNIA GAS CO
# 819                          PACIFIC GAS & ELECTRIC CO
# 820                         SOUTHERN CALIFORNIA GAS CO
# 821                          PACIFIC GAS & ELECTRIC CO
# 822                                CONSUMERS ENERGY CO
# 823                               ATLANTA GAS LIGHT CO
#
#                                              NARRATIVE  EST_COST_GAS_RELEASED
# 0    A FIRE AT AN UNOCCUPIED HOME OCCURRED AT APPRO...                    0.0
# 1    CONTRACTOR BORING ELECTRIC LINE PARALLEL TO 3"...                 2500.0
# 2    ON 2/22/10 PINETOP FIRE DEPARTMENT RESPONDED T...                   75.0
# 3    CREW WAS DIGGING A HOLE TO FIX A SERVICE LINE ...                    5.0
# 4    A SAN JUAN COUNTY DEPUTY SHERIFF WAS IN PURSUI...                   35.0
# 5    2" POLYETHYLENE GAS MAIN WAS PUNCTURED DURING ...                  150.0
# 6    A VEHICLE TRAVELING EAST ON HERMITAGE DRIVE LE...                  153.0
# 7    AMERENIP RECEIVED A CALL FROM AN OCCUPANT AT A...                    0.0
# 8    CONTRACTOR INSTALLING WATER TAP AND HIT LINE W...                  487.0
# 9    QUESTAR GAS EMERGENCY DISPATCH RECEIVED A CALL...                  151.0
# 10   BUBBLES WERE OBSERVED AND AN ODOR OF NATURAL G...                   70.0
# 11   AT APPROXIMATELY 3:05AM PUBLIC SERVICE ELECTRI...                33675.0
# 12   NATURAL GAS FROM CRACKED STEEL MAIN MIGRATED I...                 1100.0
# 13                                        SEE ATTACHED                   29.0
# 14   MR. PHILLIP VALDEZ, GAS, WATER, AND SEWER SUPE...                  450.0
# 15   GAS TRAVELED FROM A DAMAGED 3" POLY MAIN TO 50...                 8215.0
# 16   THIS IS A "FIRE FIRST" INCIDENT.  A FIRE START...                   10.0
# 17   RLA INVESTMENTS, INC. IS PERFORMING MAINTENANC...                   24.0
# 18   AT APPROXIMATELY 12:42 PM, PUBLIC SERVICE ELEC...                 7340.0
# 19   ON 1/19/10 AT APPROXIMATELY 1627 HOURS A 6.5 M...                    NaN
# 20   A HOUSE EXPLOSION AND FIRE OCCURRED AT APPROXI...                    NaN
# 21   ON MONDAY, JANUARY 25, 2010 AT APPROXIMATELY 2...                   50.0
# 22   LIGHTENING STRUCK A TREE AND THE METER SET RES...                    0.0
# 23                                                 NaN                   95.0
# 24   ON APRIL 19, 2010, AT APPROXIMATELY 10:58AM A ...                36664.0
# 25   ON MAY 11, 2010, AT APPROXIMATELY 12:05PM SCE&...                   30.0
# 26   AQUA AMERICA'S CONTRACT CREW, DANELLA, STRUCK ...                  120.0
# 27   WASHINGTON GAS RESPONDED TO THE SCENE OF A HOU...                    5.0
# 28   **** 6/10/11 ****  FINAL REPORT - ON MAY 27 AN...                  100.0
# 29         KPSC EXTERNAL/INVESTIGATION REPORT ATTACHED                   11.0
# ..                                                 ...                    ...
# 794  ON 4/25/17, A UTILITY CONTRACTOR STRUCK AN 8 I...                    1.0
# 795  P/L # 2017-0079    SOUTHWEST GAS CORPORATION (...                 2000.0
# 796  ON 03-17-17 AT 0107 HRS. WASHINGTON GAS WAS NO...                   25.0
# 797  CONTRACTOR WAS DIGGING A SEWER LINE. THE BACK ...                16936.0
# 798  A FORKLIFT DRIVER WORKING AT THE LOCATION STRU...                  232.0
# 799  ON MAY 8TH, 2017 A LEAK WAS DISCOVERED NEAR 62...                 1350.0
# 800  A VEHICLE TRAVELING ON W. WASHINGTON STREET VE...                45083.0
# 801  INCIDENT IS STILL UNDER INVESTIGATION. DELAY I...                    4.0
# 802  ILLINOIS IRRIGATION SERVICES LLC HAD HIT A 2 I...                  662.0
# 803  P/L # 2017-0079    SOUTHWEST GAS CORPORATION (...                  544.0
# 804  ON FRIDAY, JUNE 9, 2017, AN EXCAVATOR GRADING ...                 1798.0
# 805  IN FEBRUARY, A LEAK WAS IDENTIFIED NEAR THIS A...                  400.0
# 806  DRIVER LOST CONTROL OF VEHICLE AND DAMAGED REG...                   27.0
# 807  THE COMPANY WAS NOTIFIED AT 10:07 OF A FIRE TH...                  198.0
# 808  ON THURSDAY, JUNE 22, 2017, VECTREN ENERGY DEL...                 1085.0
# 809  P/L 2017-0342    SOUTHWEST GAS CORPORATION (SW...                   11.0
# 810  ON JUNE 20, 2017, A THIRD PARTY CONTRACTOR WAS...                  291.0
# 811  ON FRIDAY, JULY 7, 2017, AT 11:12 AM, PSE&G RE...                  400.0
# 812  ON JUNE THE 28TH AT 4:53 PM CST, A BUILDING ON...                  500.0
# 813  UGI EMPLOYEES WERE RESPONDING TO A LEAK CALL W...                    0.0
# 814  ON JULY 3, 2017, AT 0842 HOURS, PG&E WAS NOTIF...                 1000.0
# 815  ON JULY 3RD, 2017, FIRE DEPARTMENT REPORTED AN...                  240.0
# 816  ON THE EVENING OF JULY 22ND, A STRONG THUNDERS...                   50.0
# 817  ON 7/10/2017 AT 13:29, NATIONAL GRID DISPATCH ...                 1512.0
# 818  ON 7/8/17, A 3RD PARTY CONTRACTOR WAS DISCING ...                12000.0
# 819  ON JULY 21, 2017 AT 0911 HOURS, PG&ES GAS CONS...                 8000.0
# 820  ON JULY 26TH, 2017, CAL FIRE DEPARTMENT REPORT...                    0.0
# 821  ON JULY 27, 2017 AT 1401 HOURS, PG&E RECEIVED ...                14700.0
# 822  ON FRIDAY, JULY 28 2017 AT APPROXIMATELY 1600 ...                   75.0
# 823  A 4-INCH PLASTIC MAIN WITH ONE-WAY FEED WAS RU...                 1056.0
#
# [824 rows x 6 columns]

# %%
df2.CAUSE.value_counts()
# Out:
# OTHER OUTSIDE FORCE DAMAGE          272
# EXCAVATION DAMAGE                   236
# OTHER INCIDENT CAUSE                 99
# NATURAL FORCE DAMAGE                 61
# MATERIAL FAILURE OF PIPE OR WELD     51
# INCORRECT OPERATION                  47
# EQUIPMENT FAILURE                    41
# CORROSION FAILURE                    17
# Name: CAUSE, dtype: int64

# %%
df2['CAUSE'][df2.CAUSE == "OTHER OUTSIDE FORCE DAMAGE"] = 'other'
df2['CAUSE'][df2.CAUSE == "EXCAVATION DAMAGE"] = 'sabotage'
df2['CAUSE'][df2.CAUSE == "OTHER INCIDENT CAUSE"] = 'other'
df2['CAUSE'][df2.CAUSE == "NATURAL FORCE DAMAGE"] = 'natural disasters'
df2['CAUSE'][df2.CAUSE == "MATERIAL FAILURE OF PIPE OR WELD"] = 'leaks and spills'
df2['CAUSE'][df2.CAUSE == "INCORRECT OPERATION"] = 'technical failure'

df2['CAUSE'][df2.CAUSE == "EQUIPMENT FAILURE"] = 'maintenance'
df2['CAUSE'][df2.CAUSE == "CORROSION FAILURE"] = 'maintenance'



# df2['CAUSE'][df2.CAUSE == "NATURAL FORCE DAMAGE"] = 'natural disasters'
# Out:
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df2.rename(columns = {'LOCAL_DATETIME'     :'Incident Date',
                     'NAME'       : 'Name of Owner',
                     'OPERATOR_STATE_ABBREVIATION'    : 'State',
                     'CAUSE' : 'Cause of Loss', 
                     'NARRATIVE'  : 'Text',
                     'EST_COST_GAS_RELEASED'      : 'Total Gas Released ($)'},
                      inplace = True)

# %%
df2.head()
# Out:
#         Incident Date State      Cause of Loss  \
# 0 2010-02-13 23:35:00    CA              other
# 1 2010-02-16 10:38:00    IN           sabotage
# 2 2010-02-22 20:57:00    AZ  natural disasters
# 3 2010-02-18 19:05:00    IL        maintenance
# 4 2010-02-21 01:38:00    NM              other
#
#                         Name of Owner  \
# 0           PACIFIC GAS & ELECTRIC CO
# 1  NORTHERN INDIANA PUBLIC SERVICE CO
# 2           UNISOURCE ENERGY SERVICES
# 3            NORTHERN ILLINOIS GAS CO
# 4              NEW MEXICO GAS COMPANY
#
#                                                 Text  Total Gas Released ($)
# 0  A FIRE AT AN UNOCCUPIED HOME OCCURRED AT APPRO...                     0.0
# 1  CONTRACTOR BORING ELECTRIC LINE PARALLEL TO 3"...                  2500.0
# 2  ON 2/22/10 PINETOP FIRE DEPARTMENT RESPONDED T...                    75.0
# 3  CREW WAS DIGGING A HOLE TO FIX A SERVICE LINE ...                     5.0
# 4  A SAN JUAN COUNTY DEPUTY SHERIFF WAS IN PURSUI...                    35.0

# %%
df2.insert(3, column='Name of Installation', value=data2.LOCATION_COUNTY_NAME.values.astype(str))

df2['Name of Installation'] = 'UNKNOWN (' + df2['Name of Installation'] + ' COUNTY )'

# df2['Incident Date'] =  pd.to_datetime(df2['Incident Date'], format='%m/%d/%Y')

df2['Total Gas Released ($)'] = df2['Total Gas Released ($)'].fillna(0).astype(int)

# %%
df2['Sources'] = "https://www.phmsa.dot.gov/pipeline/library/data-stats/flagged-data-files"

# %%
df2.head()
# Out:
#         Incident Date State      Cause of Loss           Name of Installation  \
# 0 2010-02-13 23:35:00    CA              other  UNKNOWN (SAN JOAQUIN COUNTY )
# 1 2010-02-16 10:38:00    IN           sabotage   UNKNOWN (ST. JOSEPH COUNTY )
# 2 2010-02-22 20:57:00    AZ  natural disasters       UNKNOWN (NAVAJO COUNTY )
# 3 2010-02-18 19:05:00    IL        maintenance         UNKNOWN (COOK COUNTY )
# 4 2010-02-21 01:38:00    NM              other     UNKNOWN (SAN JUAN COUNTY )
#
#                         Name of Owner  \
# 0           PACIFIC GAS & ELECTRIC CO
# 1  NORTHERN INDIANA PUBLIC SERVICE CO
# 2           UNISOURCE ENERGY SERVICES
# 3            NORTHERN ILLINOIS GAS CO
# 4              NEW MEXICO GAS COMPANY
#
#                                                 Text  Total Gas Released ($)  \
# 0  A FIRE AT AN UNOCCUPIED HOME OCCURRED AT APPRO...                       0
# 1  CONTRACTOR BORING ELECTRIC LINE PARALLEL TO 3"...                    2500
# 2  ON 2/22/10 PINETOP FIRE DEPARTMENT RESPONDED T...                      75
# 3  CREW WAS DIGGING A HOLE TO FIX A SERVICE LINE ...                       5
# 4  A SAN JUAN COUNTY DEPUTY SHERIFF WAS IN PURSUI...                      35
#
#                                              Sources
# 0  https://www.phmsa.dot.gov/pipeline/library/dat...
# 1  https://www.phmsa.dot.gov/pipeline/library/dat...
# 2  https://www.phmsa.dot.gov/pipeline/library/dat...
# 3  https://www.phmsa.dot.gov/pipeline/library/dat...
# 4  https://www.phmsa.dot.gov/pipeline/library/dat...

# %%
writer = pd.ExcelWriter('gas_distribution_incidents_2010_to_Present.xlsx')
df2.to_excel(writer,'gd2010toPresent')
writer.save()

# %% [markdown]
# ## Gas distribution incidents: 2004 - 2009

# %%
file3 = "sources_from_links/PHMSA_Pipeline_Safety_Flagged_Incidents/gdmar2004to2009.xlsx"

# %%
data3 = pd.read_excel(file3, sheetname="gdmar2004to2009")

# %%
data3.head()
# Out:
#        DATAFILE_AS_OF  FF SIGNIFICANT SERIOUS     RPTID        DOR  \
# 0 2017-08-31 08:48:30  NO          NO      NO  20040116 2004-03-24
# 1 2017-08-31 08:48:30  NO         YES      NO  20040117 2004-03-19
# 2 2017-08-31 08:48:30  NO         YES      NO  20040118 2005-12-06
# 3 2017-08-31 08:48:30  NO         YES      NO  20040119 2004-03-24
# 4 2017-08-31 08:48:30  NO          NO      NO  20040120 2004-04-13
#
#           REPORT_TYPE  OPERATOR_ID                        NAME  \
# 0  SUPPLEMENTAL FINAL        18536          SOUTHWEST GAS CORP
# 1      ORIGINAL FINAL        12876         QUESTAR GAS COMPANY
# 2  SUPPLEMENTAL FINAL        20211    ATMOS ENERGY CORPORATION
# 3      ORIGINAL FINAL        10030        KINDER MORGAN RETAIL
# 4            ORIGINAL        18532  TEXAS GAS SERVICE COMPANY
#
#                                 OPSTREET  \
# 0                           PO BOX 98510
# 1                           PO BOX 45360
# 2                     2300 VICTORY DRIVE
# 3                         370 VAN GORDON
# 4  1301 SOUTH MOPAC EXPRESSWAY SUITE 400
#
#                          ...                         THREADSO IO_TYPE_TEXT  \
# 0                        ...                              NaN          NaN
# 1                        ...                              NaN          NaN
# 2                        ...                              NaN          NaN
# 3                        ...                              NaN          NaN
# 4                        ...                              NaN          NaN
#
#   IO_TYPEO IO_DRUG  IO_ALCO IO_QUAL  IO_QUAL_HRS  \
# 0      NaN     NaN      NaN     NaN          NaN
# 1      NaN     NaN      NaN     NaN          NaN
# 2      NaN     NaN      NaN     NaN          NaN
# 3      NaN     NaN      NaN     NaN          NaN
# 4      NaN     NaN      NaN     NaN          NaN
#
#                                                 MISC UNKNOWN_TEXT  \
# 0                                                NaN          NaN
# 1                                                NaN          NaN
# 2                                   SEE PART G BELOW          NaN
# 3  SERVICE VALVE BROKEN OFF BY THIRD PARTY MANUAL...          NaN
# 4                                                NaN          NaN
#
#                                            NARRATIVE
# 0  <P>SOUTHWEST GAS EXPERIENCED A GAS LEAK ON A 4...
# 1  PERSONNEL FROM THE UTAH STATE FIRE MARSHAL'S O...
# 2  FRACTURED PIPE UNEARTHED ON FEB.20TH 2004.  TH...
# 3                                                NaN
# 4  A CONTRACTOR STRUCK A 12" STEEL NATURAL GAS MA...
#
# [5 rows x 153 columns]

# %%
df3 = pd.DataFrame(data=data3, columns=['IDATE','ACSTATE', 'CAUSE','NAME', 'NARRATIVE', 'TOTAL_COST'])

# %%
df3.head(10)
# Out:
#        IDATE ACSTATE                          CAUSE  \
# 0 2004-02-27      AZ  MATERIAL AND/OR WELD FAILURES
# 1 2004-02-21      UT                 NATURAL FORCES
# 2 2004-02-15      GA                      CORROSION
# 3 2004-02-17      CO                          OTHER
# 4 2004-03-05      TX              EXCAVATION DAMAGE
# 5 2004-02-01      MI            INCORRECT OPERATION
# 6 2004-03-18      VA            INCORRECT OPERATION
# 7 2004-04-13      MA                          OTHER
# 8 2004-03-26      PA                          OTHER
# 9 2004-04-03      IN            INCORRECT OPERATION
#
#                                          NAME  \
# 0                          SOUTHWEST GAS CORP
# 1                         QUESTAR GAS COMPANY
# 2                    ATMOS ENERGY CORPORATION
# 3                        KINDER MORGAN RETAIL
# 4                  TEXAS GAS SERVICE COMPANY
# 5                         CONSUMERS ENERGY CO
# 6  RICHMOND DEPT OF PUBLIC UTILITIES, CITY OF
# 7                            BAY STATE GAS CO
# 8                           UGI UTILITIES INC
# 9          SOUTHERN INDIANA GAS & ELECTRIC CO
#
#                                            NARRATIVE  TOTAL_COST
# 0  <P>SOUTHWEST GAS EXPERIENCED A GAS LEAK ON A 4...       50000
# 1  PERSONNEL FROM THE UTAH STATE FIRE MARSHAL'S O...      100771
# 2  FRACTURED PIPE UNEARTHED ON FEB.20TH 2004.  TH...      100000
# 3                                                NaN     1000427
# 4  A CONTRACTOR STRUCK A 12" STEEL NATURAL GAS MA...      101759
# 5  ON FEBRUARY 1, 2004 AN EMPLOYEE WAS INVESTIGAT...      251010
# 6  ON THURSDAY, 03/19/2004 AT APPROXIMATELY 2240 ...           0
# 7  APRIL 21 2006  -----------------    THE INCIDE...      151010
# 8  AT 20:20 (APPROXIMATELY) MARCH 26, 2004 AN EXP...       60200
# 9  AT APPROXIMATELY 7:42 AM ON 4/3/04. VECTREN RE...      605000

# %%
df3.CAUSE.value_counts()
# Out:
# EXCAVATION DAMAGE                303
# OTHER OUTSIDE FORCE DAMAGE       300
# OTHER                            110
# NATURAL FORCES                    76
# MATERIAL AND/OR WELD FAILURES     42
# INCORRECT OPERATION               30
# CORROSION                         18
# EQUIPMENT                         18
# Name: CAUSE, dtype: int64

# %%
df3['CAUSE'][df3.CAUSE == "EXCAVATION DAMAGE"] = 'sabotage'

df3['CAUSE'][df3.CAUSE == "OTHER OUTSIDE FORCE DAMAGE"] = 'other'
df3['CAUSE'][df3.CAUSE == "OTHER"] = 'other'
df3['CAUSE'][df3.CAUSE == "NATURAL FORCES"] = 'natural disasters'
df3['CAUSE'][df3.CAUSE == "MATERIAL AND/OR WELD FAILURES"] = 'leaks and spills'
df3['CAUSE'][df3.CAUSE == "INCORRECT OPERATION"] = 'technical failure'
df3['CAUSE'][df3.CAUSE == "CORROSION"] = 'maintenance'

df3['CAUSE'][df3.CAUSE == "EQUIPMENT"] = 'maintenance'



# df3['CAUSE'][df3.CAUSE == "NATURAL FORCE DAMAGE"] = 'natural disasters'
# Out:
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
df3.rename(columns = {'IDATE'  :'Incident Date',
                     'NAME'   : 'Name of Owner',
                     'ACSTATE': 'State',
                     'CAUSE'   : 'Cause of Loss', 
                     'NARRATIVE'  : 'Text',
                     'TOTAL_COST'  : 'Total Gass/Property Loss ($)'},
                      inplace = True)

# %%
df3.insert(3, column='Name of Installation', value=data3.ACCOUNTY.values.astype(str))

df3['Name of Installation'] = 'UNKNOWN (' + df3['Name of Installation'] + ' COUNTY)'

# df3['Incident Date'] =  pd.to_datetime(df3['Incident Date'], format='%Y%m%d')
# df3['Name of Installation'] = df3['Name of Installation'].fillna('UNKNOWN').astype(str)
df3['Total Gass/Property Loss ($)'] = df3['Total Gass/Property Loss ($)'].fillna(0).astype(int)

# %%
df3['Sources'] = "https://www.phmsa.dot.gov/pipeline/library/data-stats/flagged-data-files"

# %%
df3.head(10)
# Out:
#   Incident Date State      Cause of Loss          Name of Installation  \
# 0    2004-02-27    AZ   leaks and spills     UNKNOWN (MARICOPA COUNTY)
# 1    2004-02-21    UT  natural disasters         UNKNOWN (UTAH COUNTY)
# 2    2004-02-15    GA        maintenance     UNKNOWN (MUSCOGEE COUNTY)
# 3    2004-02-17    CO              other   UNKNOWN (SAN MIGUEL COUNTY)
# 4    2004-03-05    TX           sabotage       UNKNOWN (TRAVIS COUNTY)
# 5    2004-02-01    MI  technical failure   UNKNOWN (LIVINGSTON COUNTY)
# 6    2004-03-18    VA  technical failure          UNKNOWN (nan COUNTY)
# 7    2004-04-13    MA              other      UNKNOWN (NORFOLK COUNTY)
# 8    2004-03-26    PA              other    UNKNOWN (LANCASTER COUNTY)
# 9    2004-04-03    IN  technical failure  UNKNOWN (VANDERBURGH COUNTY)
#
#                                 Name of Owner  \
# 0                          SOUTHWEST GAS CORP
# 1                         QUESTAR GAS COMPANY
# 2                    ATMOS ENERGY CORPORATION
# 3                        KINDER MORGAN RETAIL
# 4                  TEXAS GAS SERVICE COMPANY
# 5                         CONSUMERS ENERGY CO
# 6  RICHMOND DEPT OF PUBLIC UTILITIES, CITY OF
# 7                            BAY STATE GAS CO
# 8                           UGI UTILITIES INC
# 9          SOUTHERN INDIANA GAS & ELECTRIC CO
#
#                                                 Text  \
# 0  <P>SOUTHWEST GAS EXPERIENCED A GAS LEAK ON A 4...
# 1  PERSONNEL FROM THE UTAH STATE FIRE MARSHAL'S O...
# 2  FRACTURED PIPE UNEARTHED ON FEB.20TH 2004.  TH...
# 3                                                NaN
# 4  A CONTRACTOR STRUCK A 12" STEEL NATURAL GAS MA...
# 5  ON FEBRUARY 1, 2004 AN EMPLOYEE WAS INVESTIGAT...
# 6  ON THURSDAY, 03/19/2004 AT APPROXIMATELY 2240 ...
# 7  APRIL 21 2006  -----------------    THE INCIDE...
# 8  AT 20:20 (APPROXIMATELY) MARCH 26, 2004 AN EXP...
# 9  AT APPROXIMATELY 7:42 AM ON 4/3/04. VECTREN RE...
#
#    Total Gass/Property Loss ($)  \
# 0                         50000
# 1                        100771
# 2                        100000
# 3                       1000427
# 4                        101759
# 5                        251010
# 6                             0
# 7                        151010
# 8                         60200
# 9                        605000
#
#                                              Sources
# 0  https://www.phmsa.dot.gov/pipeline/library/dat...
# 1  https://www.phmsa.dot.gov/pipeline/library/dat...
# 2  https://www.phmsa.dot.gov/pipeline/library/dat...
# 3  https://www.phmsa.dot.gov/pipeline/library/dat...
# 4  https://www.phmsa.dot.gov/pipeline/library/dat...
# 5  https://www.phmsa.dot.gov/pipeline/library/dat...
# 6  https://www.phmsa.dot.gov/pipeline/library/dat...
# 7  https://www.phmsa.dot.gov/pipeline/library/dat...
# 8  https://www.phmsa.dot.gov/pipeline/library/dat...
# 9  https://www.phmsa.dot.gov/pipeline/library/dat...

# %%
writer = pd.ExcelWriter('gas_distribution_incidents_2004_to_2009.xlsx')
df3.to_excel(writer,'gdmar2004to2009')
writer.save()

# %% [markdown]
# ## Gas Transmission and Gathering Systems Incident Reports for 1986 - 2001

# %%
file4 = "sources_from_links/PHMSA_Pipeline_Safety_Flagged_Incidents/gtgg1986to2001.xlsx"

data4 = pd.read_excel(file4, sheetname="gtgg1986to2001")

df4 = pd.DataFrame(data=data4, columns=['IDATE','ACSTATE', 'CAUSE','NAME', 'NARRATIVE', 'TOTAL_COST'])

df4.head(10)
# Out:
#        IDATE ACSTATE                         CAUSE  \
# 0 1986-01-27      WY                         OTHER
# 1 1986-01-17      IL       DAMAGE BY OUTSIDE FORCE
# 2 1986-01-15      LA       DAMAGE BY OUTSIDE FORCE
# 3 1986-02-10      AL  CONSTRUCTION/MATERIAL DEFECT
# 4 1986-02-21      TX                         OTHER
# 5 1986-02-21      KY                         OTHER
# 6 1986-02-14      KS       DAMAGE BY OUTSIDE FORCE
# 7 1986-02-13      WV                         OTHER
# 8 1986-02-19      NV       DAMAGE BY OUTSIDE FORCE
# 9 1986-02-24      AR  CONSTRUCTION/MATERIAL DEFECT
#
#                                                 NAME  \
# 0                         PHILLIPS 66 NATURAL GAS CO
# 1                      PANHANDLE EASTERN PIPELINE CO
# 2                      COLUMBIA GULF TRANSMISSION CO
# 3                        FLORIDA GAS TRANSMISSION CO
# 4                           TRANSWESTERN PIPELINE CO
# 5                      TEXAS EASTERN GAS PIPELINE CO
# 6  KN ENERGY INC (KANSAS NEBRASKA NATURAL GAS CO ...
# 7                 CONSOLIDATED GAS TRANSMISSION CORP
# 8                                 SOUTHWEST GAS CORP
# 9           ARKANSAS LOUISIANA GAS CO (ARKLA GAS CO)
#
#                                            NARRATIVE  TOTAL_COST
# 0  PIPELINE PRESSURE WAS BEING REDUCED BY VENTING...           0
# 1  THE OPERATION OF A BACKHOE IN THE VICINITY OF ...       60000
# 2                                                NaN      120000
# 3            CRACK ON TOP OF GIRTH WELD WAS LEAKING.           0
# 4  A BROKEN BOLT IN THE COMPRESSOR CAUSED VIBRATI...      117000
# 5  THE PIPELINE RUPTURED NEAR THE SOUTH END OF A ...     1300000
# 6  LEAK REPORT COVERS A NATURAL GAS LEAK THAT OCC...           0
# 7  STATION EMPLOYEE OPENED 1" BALL VALVE ON BYPAS...         600
# 8  FLOODING OF THE TRUCKEE RIVER NEAR WADSWORTH, ...           0
# 9  LINE "S", 20" O.D. PIPELINE BLEW OUT AT 75' SE...      147354

# %%
df4.CAUSE.value_counts()
# Out:
# DAMAGE BY OUTSIDE FORCE         511
# CORROSION                       304
# OTHER                           295
# CONSTRUCTION/MATERIAL DEFECT    178
# Name: CAUSE, dtype: int64

# %%
df4['CAUSE'][df4.CAUSE == "DAMAGE BY OUTSIDE FORCE"] = 'other'
df4['CAUSE'][df4.CAUSE == "CORROSION"] = 'leaks and spills'
df4['CAUSE'][df4.CAUSE == "OTHER"] = 'other'
# df4['CAUSE'][df4.CAUSE == "NATURAL FORCES"] = 'natural disasters'
df4['CAUSE'][df4.CAUSE == "CONSTRUCTION/MATERIAL DEFECT"] = 'maintenance'
# df4['CAUSE'][df4.CAUSE == "INCORRECT OPERATION"] = 'technical failure'
df4['CAUSE'][df4.CAUSE == "EQUIPMENT"] = 'maintenance'
# df4['CAUSE'][df4.CAUSE == "NATURAL FORCE DAMAGE"] = 'natural disasters'
# Out:
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
df4.rename(columns = {'IDATE'  :'Incident Date',
                     'NAME'   : 'Name of Owner',
                     'ACSTATE': 'State',
                     'CAUSE'   : 'Cause of Loss', 
                     'NARRATIVE'  : 'Text',
                     'TOTAL_COST'  : 'Total Gass/Property Loss ($)'},
                      inplace = True)


df4.insert(3, column='Name of Installation', value=data4.ACCOUNTY.values.astype(str))

df4['Name of Installation'] = 'UNKNOWN (' + df4['Name of Installation'] + ' COUNTY)'

# df4['Incident Date'] =  pd.to_datetime(df4['Incident Date'], format='%Y%m%d')
# df4['Name of Installation'] = df4['Name of Installation'].fillna('UNKNOWN').astype(str)
df4['Total Gass/Property Loss ($)'] = df4['Total Gass/Property Loss ($)'].fillna(0).astype(int)

df4['Sources'] = "https://www.phmsa.dot.gov/pipeline/library/data-stats/flagged-data-files"

df4.head(10)
# Out:
#   Incident Date State Cause of Loss       Name of Installation  \
# 0    1986-01-27    WY         other  UNKNOWN (CAMPBELL COUNTY)
# 1    1986-01-17    IL         other    UNKNOWN (MORGAN COUNTY)
# 2    1986-01-15    LA         other  UNKNOWN (OFFSHORE COUNTY)
# 3    1986-02-10    AL   maintenance   UNKNOWN (BALDWIN COUNTY)
# 4    1986-02-21    TX         other    UNKNOWN (HARRIS COUNTY)
# 5    1986-02-21    KY         other   UNKNOWN (GARRARD COUNTY)
# 6    1986-02-14    KS         other   UNKNOWN (WALLACE COUNTY)
# 7    1986-02-13    WV         other     UNKNOWN (LEWIS COUNTY)
# 8    1986-02-19    NV         other         UNKNOWN (  COUNTY)
# 9    1986-02-24    AR   maintenance    UNKNOWN (NEVADA COUNTY)
#
#                                        Name of Owner  \
# 0                         PHILLIPS 66 NATURAL GAS CO
# 1                      PANHANDLE EASTERN PIPELINE CO
# 2                      COLUMBIA GULF TRANSMISSION CO
# 3                        FLORIDA GAS TRANSMISSION CO
# 4                           TRANSWESTERN PIPELINE CO
# 5                      TEXAS EASTERN GAS PIPELINE CO
# 6  KN ENERGY INC (KANSAS NEBRASKA NATURAL GAS CO ...
# 7                 CONSOLIDATED GAS TRANSMISSION CORP
# 8                                 SOUTHWEST GAS CORP
# 9           ARKANSAS LOUISIANA GAS CO (ARKLA GAS CO)
#
#                                                 Text  \
# 0  PIPELINE PRESSURE WAS BEING REDUCED BY VENTING...
# 1  THE OPERATION OF A BACKHOE IN THE VICINITY OF ...
# 2                                                NaN
# 3            CRACK ON TOP OF GIRTH WELD WAS LEAKING.
# 4  A BROKEN BOLT IN THE COMPRESSOR CAUSED VIBRATI...
# 5  THE PIPELINE RUPTURED NEAR THE SOUTH END OF A ...
# 6  LEAK REPORT COVERS A NATURAL GAS LEAK THAT OCC...
# 7  STATION EMPLOYEE OPENED 1" BALL VALVE ON BYPAS...
# 8  FLOODING OF THE TRUCKEE RIVER NEAR WADSWORTH, ...
# 9  LINE "S", 20" O.D. PIPELINE BLEW OUT AT 75' SE...
#
#    Total Gass/Property Loss ($)  \
# 0                             0
# 1                         60000
# 2                        120000
# 3                             0
# 4                        117000
# 5                       1300000
# 6                             0
# 7                           600
# 8                             0
# 9                        147354
#
#                                              Sources
# 0  https://www.phmsa.dot.gov/pipeline/library/dat...
# 1  https://www.phmsa.dot.gov/pipeline/library/dat...
# 2  https://www.phmsa.dot.gov/pipeline/library/dat...
# 3  https://www.phmsa.dot.gov/pipeline/library/dat...
# 4  https://www.phmsa.dot.gov/pipeline/library/dat...
# 5  https://www.phmsa.dot.gov/pipeline/library/dat...
# 6  https://www.phmsa.dot.gov/pipeline/library/dat...
# 7  https://www.phmsa.dot.gov/pipeline/library/dat...
# 8  https://www.phmsa.dot.gov/pipeline/library/dat...
# 9  https://www.phmsa.dot.gov/pipeline/library/dat...

# %%
writer = pd.ExcelWriter('gas_transmission_gathering_1986_2001.xlsx')
df4.to_excel(writer,'gtgg1986to2001')
writer.save()

# %% [markdown]
# ## Gas Transmission and Gathering Systems Incident Reports for 2002 - 2009

# %%
file5 = "sources_from_links/PHMSA_Pipeline_Safety_Flagged_Incidents/gtgg2002to2009.xlsx"

data5 = pd.read_excel(file5, sheetname="gtgg2002to2009")

df5 = pd.DataFrame(data=data5, columns=['IDATE','ACSTATE', 'CAUSE','NAME', 'NARRATIVE', 'TOTAL_COST'])

df5.head(5)
# Out:
#        IDATE ACSTATE                          CAUSE  \
# 0 2002-01-26     NaN                      CORROSION
# 1 2002-03-06      KY  MATERIAL AND/OR WELD FAILURES
# 2 2002-03-13      LA                      CORROSION
# 3 2002-02-28     NaN                          OTHER
# 4 2002-03-04      MD  MATERIAL AND/OR WELD FAILURES
#
#                               NAME  \
# 0  NORTHERN NATURAL GAS CO (ENRON)
# 1        TENNESSEE GAS PIPELINE CO
# 2          WILLIAMS FIELD SERVICES
# 3           EL PASO FIELD SERVICES
# 4  WILLIAMS GAS PIPELINE - TRANSCO
#
#                                            NARRATIVE  TOTAL_COST
# 0                                                NaN     1300000
# 1  THERE WAS A RUPTURE IN THE COMPRESSOR STATION ...     2011000
# 2  WHILE TRANSPORTING OPERATIONAL PERSONNEL BACK ...      190000
# 3  GARLAND GASPARD OF EL PASO FIELD SERVICES WAS ...      171342
# 4  COMPANY EMPLOYEE WHILE MOWING ROW FOUND GAS ES...      350000

# %%
df5.CAUSE.value_counts()
# Out:
# CORROSION                        267
# EXCAVATION DAMAGE                150
# MATERIAL AND/OR WELD FAILURES    150
# NATURAL FORCES                   148
# OTHER                            108
# OTHER OUTSIDE FORCE DAMAGE        93
# EQUIPMENT                         86
# INCORRECT OPERATION               27
# Name: CAUSE, dtype: int64

# %%
df5['CAUSE'][df5.CAUSE == "CORROSION"] = 'leaks and spills'
df5['CAUSE'][df5.CAUSE == "EXCAVATION DAMAGE"] = 'sabotage'
df5['CAUSE'][df5.CAUSE == "MATERIAL AND/OR WELD FAILURES"] = 'maintenance'
df5['CAUSE'][df5.CAUSE == "NATURAL FORCES"] = 'natural disasters'
df5['CAUSE'][df5.CAUSE == "OTHER"] = 'other'
df5['CAUSE'][df5.CAUSE == "OTHER OUTSIDE FORCE DAMAGE"] = 'other'
df5['CAUSE'][df5.CAUSE == "EQUIPMENT"] = 'maintenance'
df5['CAUSE'][df5.CAUSE == "INCORRECT OPERATION"] = 'technical failure'
# df5['CAUSE'][df5.CAUSE == "NATURAL FORCE DAMAGE"] = 'natural disasters'
# Out:
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df5.rename(columns = {'IDATE'  :'Incident Date',
                     'NAME'   : 'Name of Owner',
                     'ACSTATE': 'State',
                     'CAUSE'   : 'Cause of Loss', 
                     'NARRATIVE'  : 'Text',
                     'TOTAL_COST'  : 'Total Gass/Property Loss ($)'},
                      inplace = True)


df5.insert(3, column='Name of Installation', value=data5.ACCOUNTY.values.astype(str))

df5['Name of Installation'] = 'UNKNOWN (' + df5['Name of Installation'] + ' COUNTY)'

# df5['Incident Date'] =  pd.to_datetime(df5['Incident Date'], format='%Y%m%d')
# df5['Name of Installation'] = df5['Name of Installation'].fillna('UNKNOWN').astype(str)
df5['Total Gass/Property Loss ($)'] = df5['Total Gass/Property Loss ($)'].fillna(0).astype(int)

df5['Sources'] = "https://www.phmsa.dot.gov/pipeline/library/data-stats/flagged-data-files"

df5.head(10)
# Out:
#   Incident Date State     Cause of Loss         Name of Installation  \
# 0    2002-01-26   NaN  leaks and spills         UNKNOWN (nan COUNTY)
# 1    2002-03-06    KY       maintenance  UNKNOWN (MONTGOMERY COUNTY)
# 2    2002-03-13    LA  leaks and spills  UNKNOWN (TERREBONNE COUNTY)
# 3    2002-02-28   NaN             other         UNKNOWN (nan COUNTY)
# 4    2002-03-04    MD       maintenance      UNKNOWN (HOWARD COUNTY)
# 5    2002-03-15    MI  leaks and spills        UNKNOWN (IRON COUNTY)
# 6    2002-03-18    IL          sabotage        UNKNOWN (COOK COUNTY)
# 7    2002-02-22    NE             other      UNKNOWN (DAKOTA COUNTY)
# 8    2002-03-26    WY       maintenance      UNKNOWN (CARBON COUNTY)
# 9    2002-03-26    OH  leaks and spills     UNKNOWN (JACKSON COUNTY)
#
#                               Name of Owner  \
# 0           NORTHERN NATURAL GAS CO (ENRON)
# 1                 TENNESSEE GAS PIPELINE CO
# 2                   WILLIAMS FIELD SERVICES
# 3                    EL PASO FIELD SERVICES
# 4           WILLIAMS GAS PIPELINE - TRANSCO
# 5           GREAT LAKES GAS TRANSMISSION CO
# 6  NATURAL GAS PIPELINE CO OF AMERICA (KMI)
# 7           NORTHERN NATURAL GAS CO (ENRON)
# 8                COLORADO INTERSTATE GAS CO
# 9                 TENNESSEE GAS PIPELINE CO
#
#                                                 Text  \
# 0                                                NaN
# 1  THERE WAS A RUPTURE IN THE COMPRESSOR STATION ...
# 2  WHILE TRANSPORTING OPERATIONAL PERSONNEL BACK ...
# 3  GARLAND GASPARD OF EL PASO FIELD SERVICES WAS ...
# 4  COMPANY EMPLOYEE WHILE MOWING ROW FOUND GAS ES...
# 5  UPON COMPLETION OF THE FAILURE INVESTIGATION, ...
# 6                                                NaN
# 7  LEAKING GAS WAS REPORTED BY A CONTRACTOR WHO W...
# 8  A LEAK WAS DISCOVERED DURING F 1 LEAK SURVEY O...
# 9  THERE WAS A LEAK NEAR MP 202-4 + 14.0.  WHILE ...
#
#    Total Gass/Property Loss ($)  \
# 0                       1300000
# 1                       2011000
# 2                        190000
# 3                        171342
# 4                        350000
# 5                       3104629
# 6                          1810
# 7                         73000
# 8                        145000
# 9                         70000
#
#                                              Sources
# 0  https://www.phmsa.dot.gov/pipeline/library/dat...
# 1  https://www.phmsa.dot.gov/pipeline/library/dat...
# 2  https://www.phmsa.dot.gov/pipeline/library/dat...
# 3  https://www.phmsa.dot.gov/pipeline/library/dat...
# 4  https://www.phmsa.dot.gov/pipeline/library/dat...
# 5  https://www.phmsa.dot.gov/pipeline/library/dat...
# 6  https://www.phmsa.dot.gov/pipeline/library/dat...
# 7  https://www.phmsa.dot.gov/pipeline/library/dat...
# 8  https://www.phmsa.dot.gov/pipeline/library/dat...
# 9  https://www.phmsa.dot.gov/pipeline/library/dat...

# %%
writer = pd.ExcelWriter('gas_transmission_gathering_2002_to_2009.xlsx')
df5.to_excel(writer,'gtgg2002to2009')
writer.save()

# %% [markdown]
# ## GAS TRANSMISSION AND GATHERING PIPELINE SYSTEMS 2010 - Present

# %%
file6 = "sources_from_links/PHMSA_Pipeline_Safety_Flagged_Incidents/gtggungs2010toPresent.xlsx"

data6 = pd.read_excel(file6, sheetname="gtggungs2010toPresent")

df6 = pd.DataFrame(data=data6, columns=['LOCAL_DATETIME','OPERATOR_STATE_ABBREVIATION', 'CAUSE','NAME', 'NARRATIVE', 'EST_COST_GAS_RELEASED'])
df6.head(5)
# Out:
#        LOCAL_DATETIME OPERATOR_STATE_ABBREVIATION                 CAUSE  \
# 0 2010-02-09 01:32:00                          OK  NATURAL FORCE DAMAGE
# 1 2010-01-06 04:32:00                          AL     CORROSION FAILURE
# 2 2010-02-16 08:18:00                          OK     EQUIPMENT FAILURE
# 3 2010-02-17 04:40:00                          TX     EQUIPMENT FAILURE
# 4 2010-02-19 10:03:00                          OK     EQUIPMENT FAILURE
#
#                                   NAME  \
# 0  CENTERPOINT ENERGY GAS TRANSMISSION
# 1              SOUTHERN NATURAL GAS CO
# 2  CENTERPOINT ENERGY GAS TRANSMISSION
# 3    ENTERPRISE PRODUCTS OPERATING LLC
# 4                           ENOGEX LLC
#
#                                            NARRATIVE  EST_COST_GAS_RELEASED
# 0  THE REGULATOR FOR THE PNEUMATIC ACTUATOR FROZE...               172714.0
# 1  ON JANUARY 6 2010 SOUTHERN NATURAL GAS (SNG) C...               242699.0
# 2  AT APPROXIMATELY 08:18 HRS ON FEBRUARY 22, A F...                 6429.0
# 3  ON FEBRUARY 17, 2010 THE WISE COUNTY COMPRESSO...               189000.0
# 4  AT 10:03 AM AN I&E TECHNICIAN WAS WORKING INSI...                10850.0

# %%
df6.CAUSE.value_counts()
# Out:
# EQUIPMENT FAILURE                   262
# CORROSION FAILURE                   196
# EXCAVATION DAMAGE                   120
# MATERIAL FAILURE OF PIPE OR WELD    109
# NATURAL FORCE DAMAGE                 70
# OTHER INCIDENT CAUSE                 58
# OTHER OUTSIDE FORCE DAMAGE           57
# INCORRECT OPERATION                  48
# Name: CAUSE, dtype: int64

# %%
df6['CAUSE'][df6.CAUSE == "EQUIPMENT FAILURE"] = 'maintenance'

df6['CAUSE'][df6.CAUSE == "CORROSION FAILURE"] = 'leaks and spills'
df6['CAUSE'][df6.CAUSE == "EXCAVATION DAMAGE"] = 'sabotage'
df6['CAUSE'][df6.CAUSE == "MATERIAL FAILURE OF PIPE OR WELD"] = 'maintenance'
df6['CAUSE'][df6.CAUSE == "NATURAL FORCE DAMAGE"] = 'natural disasters'
df6['CAUSE'][df6.CAUSE == "OTHER INCIDENT CAUSE"] = 'other'
df6['CAUSE'][df6.CAUSE == "OTHER OUTSIDE FORCE DAMAGE"] = 'other'
df6['CAUSE'][df6.CAUSE == "INCORRECT OPERATION"] = 'technical failure'
# df6['CAUSE'][df6.CAUSE == "NATURAL FORCE DAMAGE"] = 'natural disasters'
# Out:
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/Tai/anaconda3/envs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df6.rename(columns = {'LOCAL_DATETIME'  :'Incident Date',
                     'NAME'   : 'Name of Owner',
                     'OPERATOR_STATE_ABBREVIATION': 'State',
                     'CAUSE'   : 'Cause of Loss', 
                     'NARRATIVE'  : 'Text',
                     'EST_COST_GAS_RELEASED'  : 'Total Gass/Property Loss ($)'},
                      inplace = True)


df6.insert(3, column='Name of Installation', value=data6.ONSHORE_COUNTY_NAME.values.astype(str))

df6['Name of Installation'] = 'UNKNOWN (' + df6['Name of Installation'] + ' COUNTY)'

# df6['Incident Date'] =  pd.to_datetime(df6['Incident Date'], format='%Y%m%d')
# df6['Name of Installation'] = df6['Name of Installation'].fillna('UNKNOWN').astype(str)
df6['Total Gass/Property Loss ($)'] = df6['Total Gass/Property Loss ($)'].fillna(0).astype(int)

df6['Sources'] = "https://www.phmsa.dot.gov/pipeline/library/data-stats/flagged-data-files"

df6.head(10)
# Out:
#         Incident Date State      Cause of Loss  \
# 0 2010-02-09 01:32:00    OK  natural disasters
# 1 2010-01-06 04:32:00    AL   leaks and spills
# 2 2010-02-16 08:18:00    OK        maintenance
# 3 2010-02-17 04:40:00    TX        maintenance
# 4 2010-02-19 10:03:00    OK        maintenance
# 5 2010-03-02 04:20:00    KY        maintenance
# 6 2010-03-05 12:30:00    CA              other
# 7 2010-03-01 14:00:00    TX        maintenance
# 8 2010-03-06 15:30:00    AL              other
# 9 2010-01-21 12:29:00    TX        maintenance
#
#                   Name of Installation  \
# 0              UNKNOWN (CUSTER COUNTY)
# 1             UNKNOWN (WINSTON COUNTY)
# 2  UNKNOWN (ROFER MILLS COUNTY COUNTY)
# 3                UNKNOWN (WISE COUNTY)
# 4            UNKNOWN (OKLAHOMA COUNTY)
# 5                UNKNOWN (RENO COUNTY)
# 6              UNKNOWN (SOLANO COUNTY)
# 7              UNKNOWN (MOJAVE COUNTY)
# 8                 UNKNOWN (nan COUNTY)
# 9              UNKNOWN (COPIAH COUNTY)
#
#                              Name of Owner  \
# 0      CENTERPOINT ENERGY GAS TRANSMISSION
# 1                  SOUTHERN NATURAL GAS CO
# 2      CENTERPOINT ENERGY GAS TRANSMISSION
# 3        ENTERPRISE PRODUCTS OPERATING LLC
# 4                               ENOGEX LLC
# 5  SOUTHERN STAR CENTRAL GAS PIPELINE, INC
# 6                PACIFIC GAS & ELECTRIC CO
# 7                   EL PASO NATURAL GAS CO
# 8      TENNESSEE GAS PIPELINE CO (EL PASO)
# 9             SOUTHEAST SUPPLY HEADER, LLC
#
#                                                 Text  \
# 0  THE REGULATOR FOR THE PNEUMATIC ACTUATOR FROZE...
# 1  ON JANUARY 6 2010 SOUTHERN NATURAL GAS (SNG) C...
# 2  AT APPROXIMATELY 08:18 HRS ON FEBRUARY 22, A F...
# 3  ON FEBRUARY 17, 2010 THE WISE COUNTY COMPRESSO...
# 4  AT 10:03 AM AN I&E TECHNICIAN WAS WORKING INSI...
# 5  AT 4:20AM THE GAS CONTROLLER NOTICED A PRESSUR...
# 6  A FIRE OCCURRED AT APPROXIMATELY 1230 HOURS ON...
# 7  AN ANOMALY INDICATION FROM AN ILI RUN WAS BEIN...
# 8  ON MARCH 6, 2010, A 15 FEET DIAMETER GAS BUBBL...
# 9  ON JANUARY 21, 2010, A SOUTHERN PINES ELECTRIC...
#
#    Total Gass/Property Loss ($)  \
# 0                        172714
# 1                        242699
# 2                          6429
# 3                        189000
# 4                         10850
# 5                        313880
# 6                             0
# 7                             0
# 8                             0
# 9                          1310
#
#                                              Sources
# 0  https://www.phmsa.dot.gov/pipeline/library/dat...
# 1  https://www.phmsa.dot.gov/pipeline/library/dat...
# 2  https://www.phmsa.dot.gov/pipeline/library/dat...
# 3  https://www.phmsa.dot.gov/pipeline/library/dat...
# 4  https://www.phmsa.dot.gov/pipeline/library/dat...
# 5  https://www.phmsa.dot.gov/pipeline/library/dat...
# 6  https://www.phmsa.dot.gov/pipeline/library/dat...
# 7  https://www.phmsa.dot.gov/pipeline/library/dat...
# 8  https://www.phmsa.dot.gov/pipeline/library/dat...
# 9  https://www.phmsa.dot.gov/pipeline/library/dat...

# %%
writer = pd.ExcelWriter('gas_transmission_gathering_2010_to_Present.xlsx')
df6.to_excel(writer,'gtggungs2010toPresent')
writer.save()
